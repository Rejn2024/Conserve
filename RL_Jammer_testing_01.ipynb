# %% [markdown]
# # RL Jammer DSP acceleration prototype (`RL_Jammer_testing.ipynb`)
#
# This notebook **implements** (not just documents) DSP-chain accelerations:
# - vectorized/batched STFT feature extraction,
# - cached DSP constants (window/frequency grid),
# - decode scheduling for reward computation,
# - batched decode calls through `rx_command_iq_broadcast`,
# - resample short-circuit when sample rates match.

# %%
from __future__ import annotations

from dataclasses import dataclass
from typing import Any, Dict, List, Sequence, Tuple
import numpy as np
import torch
from pathlib import Path
import os
# import advanced_link_skdsp_v6_robust as link6
import advanced_link_skdsp_v7_robust as link7
import score_iq_decode as scorer

from accelerated_training_utils import JammerVecEnv, jammer_controller_batch, repeat_to_length_mod

if not hasattr(np, "bool8"):
    np.bool8 = np.bool_

from torch.utils.tensorboard import SummaryWriter

from accelerated_training_utils import (JammerVecEnv,
                                        build_stft_observation_from_iq_batch,
                                        jammer_controller_batch)
from tx_controller_tone_pulse_stft_varlen_5 import (ActorCritic,
                                                    TonePulseTXControlNetVarLen,
                                                    build_controlled_tone_pulse_batch_from_iq_batches)

from accelerated_training_utils import (
    precompute_training_cache,
    create_cached_dataloader,
    run_epoch_cached,
    maybe_compile_model,
)

# %%
# Discrete action space size consumed by tx_controller_tone_pulse_stft_varlen_3.ActorCritic
ACTION_DIM = 75

# %%
_DSP_CACHE: Dict[Tuple[str, int, int, float], Dict[str, torch.Tensor]] = {}


def _get_stft_constants(device: torch.device,
                        nfft: int,
                        nperseg: int,
                        sample_rate_hz: float) -> Dict[str, torch.Tensor]:
    key = (str(device), int(nfft), int(nperseg), float(sample_rate_hz))
    cached = _DSP_CACHE.get(key)
    if cached is not None:
        return cached

    window = torch.hann_window(nperseg, dtype=torch.float32, device=device)
    fgrid = torch.fft.fftshift(
        torch.fft.fftfreq(nfft, d=1.0 / max(float(sample_rate_hz), 1.0)).to(device)
    ).to(torch.float32)
    out = {"window": window, "fgrid": fgrid}
    _DSP_CACHE[key] = out
    return out


def preprocess_batched_iq_to_stft_feature_fast(
    iq_batch: torch.Tensor,
    sample_rate_hz: float,
    nperseg: int = 128,
    noverlap: int = 96,
    nfft: int = 128,
    out_channels: int = 14,
) -> Dict[str, torch.Tensor]:
    """Vectorized STFT preprocessing for a complex IQ batch [B, T]."""
    if not torch.is_tensor(iq_batch):
        iq_batch = torch.as_tensor(iq_batch)
    if iq_batch.ndim != 2:
        raise ValueError(f"iq_batch must be [B, T], got {tuple(iq_batch.shape)}")

    x = iq_batch.to(dtype=torch.complex64)
    if x.shape[1] < 8:
        x = torch.nn.functional.pad(x, (0, 8 - x.shape[1]))

    x = x - x.mean(dim=1, keepdim=True)
    scale = torch.median(torch.abs(x), dim=1, keepdim=True).values
    x = x / (scale + 1e-6)

    nperseg_eff = int(min(nperseg, max(8, x.shape[1])))
    noverlap_eff = int(min(noverlap, nperseg_eff - 1))
    hop_length = max(1, nperseg_eff - noverlap_eff)

    const = _get_stft_constants(device=x.device, nfft=nfft, nperseg=nperseg_eff, sample_rate_hz=sample_rate_hz)

    z = torch.stft(
        x,
        n_fft=nfft,
        hop_length=hop_length,
        win_length=nperseg_eff,
        window=const["window"],
        center=False,
        return_complex=True,
    )
    z = torch.fft.fftshift(z, dim=1)

    mag = torch.log1p(torch.abs(z)).to(torch.float32)
    phase = torch.angle(z).to(torch.float32)
    real = z.real.to(torch.float32)
    imag = z.imag.to(torch.float32)
    power = (torch.abs(z) ** 2).to(torch.float32)
    power_log = torch.log1p(power)

    f = const["fgrid"][None, :, None]
    denom = power.sum(dim=1, keepdim=True) + 1e-12
    centroid = (f * power).sum(dim=1, keepdim=True) / denom
    centroid_plane = centroid.repeat(1, mag.shape[1], 1) / max(float(sample_rate_hz), 1.0)

    spread = torch.sqrt((((f - centroid) ** 2) * power).sum(dim=1, keepdim=True) / denom + 1e-12)
    spread_plane = (spread / max(float(sample_rate_hz), 1.0)).repeat(1, mag.shape[1], 1)

    flatness = torch.exp(torch.mean(torch.log(torch.clamp(power, min=1e-12)), dim=1, keepdim=True))
    flatness = flatness / (power.mean(dim=1, keepdim=True) + 1e-12)
    flatness_plane = flatness.repeat(1, mag.shape[1], 1)

    frame_power = power.mean(dim=1, keepdim=True)
    frame_power_norm = frame_power / (frame_power.mean(dim=2, keepdim=True) + 1e-12)
    frame_power_plane = frame_power_norm.repeat(1, mag.shape[1], 1)

    delta_t_mag = torch.diff(mag, dim=2, prepend=mag[:, :, :1])
    delta_f_mag = torch.diff(mag, dim=1, prepend=mag[:, :1, :])
    delta_t_power = torch.diff(power_log, dim=2, prepend=power_log[:, :, :1])
    delta_t_phase = torch.diff(phase, dim=2, prepend=phase[:, :, :1])

    sr_plane = torch.full_like(mag, torch.log10(torch.tensor(max(float(sample_rate_hz), 1.0), device=mag.device)) / 10.0)

    feat = torch.stack(
        [
            mag,
            phase,
            centroid_plane,
            sr_plane,
            real,
            imag,
            power_log,
            delta_t_mag,
            delta_f_mag,
            delta_t_phase,
            delta_t_power,
            spread_plane,
            flatness_plane,
            frame_power_plane,
        ][:out_channels],
        dim=1,
    )

    peak_bin = torch.argmax(power.mean(dim=2), dim=1)
    peak_hz = const["fgrid"][peak_bin]
    rx_power = (x.abs() ** 2).mean(dim=1)

    return {
        "feature": feat.to(torch.float32),
        "rx_power": rx_power.to(torch.float32),
        "peak_hz": peak_hz.to(torch.float32),
        "lengths": torch.full((x.shape[0],), float(x.shape[1]), device=x.device, dtype=torch.float32),
    }

# %%
def build_stft_observation_fast(
    *,
    iq1: torch.Tensor,
    iq2: torch.Tensor,
    iq3: torch.Tensor,
    intake_sample_rate_hz: float,
    device: str = "cpu",
) -> Dict[str, List[torch.Tensor]]:
    p1 = preprocess_batched_iq_to_stft_feature_fast(iq1, intake_sample_rate_hz)
    p2 = preprocess_batched_iq_to_stft_feature_fast(iq2, intake_sample_rate_hz)
    p3 = preprocess_batched_iq_to_stft_feature_fast(iq3, intake_sample_rate_hz)
    return {
        "stft_feature_list": [
            p1["feature"].to(device=device, dtype=torch.float32, non_blocking=True),
            p2["feature"].to(device=device, dtype=torch.float32, non_blocking=True),
            p3["feature"].to(device=device, dtype=torch.float32, non_blocking=True),
        ]
    }

# %%
@dataclass
class RewardScheduleConfig:
    decode_every_n_steps: int = 4
    proxy_reward_scale: float = 0.01


def _batched_decode(iq_batch: torch.Tensor, meta_list: Sequence[Dict[str, Any]]) -> List[Dict[str, Any]]:
    if hasattr(link7, "rx_command_iq_broadcast"):
        return link7.rx_command_iq_broadcast(iq_batch, list(meta_list))
    return [link7.rx_command_iq(iq_batch[i], meta_list[i]) for i in range(iq_batch.shape[0])]


def compute_rewards_scheduled_batched(
    *,
    jam_batch: Sequence[Dict[str, Any]],
    samples: Sequence[Dict[str, Any]],
    jammer_sampling_freq: float,
    device: str,
    step_idx: int,
    sched: RewardScheduleConfig,
) -> Tuple[torch.Tensor, int, int]:
    """Batched reward computation with decode scheduling + resample short-circuit."""
    dev = torch.device(device)
    # do_decode = (step_idx % max(1, int(sched.decode_every_n_steps)) == 0)

    jammed_rows: List[torch.Tensor] = []
    metas: List[Dict[str, Any]] = []
    proxy_rewards: List[torch.Tensor] = []

    for jam_item, sample in zip(jam_batch, samples):
        tx_iq = jam_item["tx_iq"].to(dtype=torch.complex64)
        whole_iq = sample["whole_iq"].to(dtype=torch.complex64)
        whole_meta = sample["whole_meta"]
        sr_out = float(whole_meta["sample_rate_hz"])

        if abs(float(jammer_sampling_freq) - sr_out) < 1e-6:
            tx_rs = tx_iq
        else:
            tx_rs = link7.resample_iq(tx_iq, fs_in_hz=float(jammer_sampling_freq), fs_out_hz=sr_out)

        tx_rs = repeat_to_length_mod(tx_rs, int(whole_iq.shape[0]))
        tx_rs = torch.as_tensor(tx_rs[: whole_iq.shape[0]], dtype=torch.complex64)

        jammed = whole_iq.to(device) + tx_rs.to(device)
        jammed_rows.append(jammed.to(dev))
        metas.append(whole_meta)

        # proxy = -sched.proxy_reward_scale * torch.mean(torch.abs(tx_rs) ** 2)
        # proxy_rewards.append(proxy.to(torch.float32))

    if not jammed_rows:
        return torch.zeros(0, dtype=torch.float32, device=dev), 0, 0

    # if not do_decode:
    #     return torch.stack(proxy_rewards).to(device=dev), 0, 0

    max_len = max(int(x.numel()) for x in jammed_rows)
    jammed_pad = [torch.nn.functional.pad(x, (0, max_len - int(x.numel()))) for x in jammed_rows]
    jammed_batch = torch.stack(jammed_pad, dim=0).to(device=dev, dtype=torch.complex64)

    results = _batched_decode(jammed_batch, metas)

    scores: List[torch.Tensor] = []
    success = 0
    total = 0
    for r, m in zip(results, metas):
        total += 1
        s = float(
            r.score_decode(r, m)) if r is not None else 0.0
        if s < 1.0:
            success += 1
        scores.append(torch.tensor(s, dtype=torch.float32, device=dev))

    return torch.stack(scores), success, total

# %%
def _resolve_steps_per_epoch_for_notebook(env: JammerVecEnv, rollout_steps: int = 0) -> int:
    if int(rollout_steps) > 0:
        return int(rollout_steps)
    if hasattr(env, "_source_batches_per_epoch") and int(getattr(env, "_source_batches_per_epoch", 0)) > 0:
        return int(env._source_batches_per_epoch)
    sample_count = len(getattr(env, "samples", []))
    return max(1, int(np.ceil(sample_count / max(1, int(env.num_envs)))))


@torch.no_grad()
def _evaluate_split_metrics_batched_dsp(
    policy: torch.nn.Module,
    env: JammerVecEnv,
    split: str,
    device: str,
    value_coef: float,
    reward_sched: RewardScheduleConfig,
) -> Tuple[float, float]:
    split_samples = getattr(env, "test_samples", None) if split == "test" else getattr(env, "samples", None)
    if not split_samples:
        return float("inf"), 0.0

    logp_buf: List[torch.Tensor] = []
    rew_buf: List[torch.Tensor] = []
    val_buf: List[torch.Tensor] = []
    decode_successes = 0
    decode_total = 0
    eval_step_idx = 0

    original_mode = env.mode
    original_active = list(getattr(env, "_active", []))
    original_step_count = int(getattr(env, "_step_count", 0))

    try:
        env.set_mode(split)
        obs = env.reset()
        eval_steps = _resolve_steps_per_epoch_for_notebook(env, 0)

        for _ in range(eval_steps):
            model_obs = build_stft_observation_fast(
                iq1=obs["iq1"],
                iq2=obs["iq2"],
                iq3=obs["iq3"],
                intake_sample_rate_hz=float(env.jammer_sampling_freq),
                device=device,
            )
            action_t, value_t, logp_t = policy.get_action_value_logp(model_obs)
            actions = action_t.squeeze()
            if env.num_envs == 1 and isinstance(actions, torch.Tensor) and actions.ndim >= 1:
                action_batch = [actions]
            else:
                action_batch = actions

            if not getattr(env, "_active", None):
                env._active = env._next_samples()
            active_samples = list(env._active)

            jam_batch = jammer_controller_batch(
                model=env.model,
                samples=active_samples,
                actions=action_batch,
                jammer_sampling_freq=env.jammer_sampling_freq,
                user_peak_power_fraction=env.user_peak_power_fraction,
                device=env.device,
            )

            rewards_t, success, total = compute_rewards_scheduled_batched(
                jam_batch=jam_batch,
                samples=active_samples,
                jammer_sampling_freq=float(env.jammer_sampling_freq),
                device=device,
                step_idx=eval_step_idx,
                sched=reward_sched,
            )
            eval_step_idx += 1
            decode_successes += int(success)
            decode_total += int(total)

            env._step_count += 1
            done = env._step_count >= env.max_steps
            if done:
                env._active = env._next_samples()
                env._step_count = 0
            obs = env._obs_from_samples(env._active)

            logp_buf.append(logp_t)
            val_buf.append(value_t)
            rew_buf.append(rewards_t.to(device=device, dtype=torch.float32))

        returns = torch.stack(rew_buf, dim=0)
        values = torch.stack(val_buf, dim=0)
        logps = torch.stack(logp_buf, dim=0)
        if logps.ndim > returns.ndim:
            logps = logps.squeeze(-1)
        if values.ndim > returns.ndim:
            values = values.squeeze(-1)

        adv =  returns  - values.detach()
        adv = adv / (returns.std(unbiased=False) + 1)
        policy_loss = -(logps * adv.detach()).mean()
        critic_loss = torch.nn.functional.mse_loss(values, returns)
        loss = policy_loss + value_coef * critic_loss
        # print(f" test logps.mean() : {logps.mean()}")
        # print(f" test adv.mean() : {adv.mean()}")

        decode_pct = (100.0 * decode_successes / decode_total) if decode_total else 0.0

        return float(loss.item()), float(decode_pct)
    finally:
        env.set_mode(original_mode)
        env._active = original_active
        env._step_count = original_step_count


def train_rl_loop_batched_dsp(
    policy: torch.nn.Module,
    env: JammerVecEnv,
    cfg: Any,
    reward_sched: RewardScheduleConfig,
):
    """PPO-style RL loop that uses one JammerVecEnv for train/test, epoch-wise eval, and checkpointing."""
    device = getattr(cfg, "device", "cuda" if torch.cuda.is_available() else "cpu")
    lr = float(getattr(cfg, "lr", 3e-4))
    epochs = max(1, int(getattr(cfg, "epochs", 1)))
    updates = max(1, int(getattr(cfg, "updates", 1)))
    value_coef = float(getattr(cfg, "value_coef", 0.5))
    rollout_steps = int(getattr(cfg, "rollout_steps", 0))

    optimizer = torch.optim.Adam(policy.parameters(), lr=lr)
    steps_per_epoch = _resolve_steps_per_epoch_for_notebook(env, rollout_steps)

    writer = SummaryWriter(log_dir=getattr(cfg, "tensorboard_log_dir", "runs/train_rl_loop_batched_dsp"))
    checkpoint_dir = Path(getattr(cfg, "checkpoint_dir", "checkpoints_rl_batched_dsp"))
    checkpoint_dir.mkdir(parents=True, exist_ok=True)
    best_checkpoint_path = checkpoint_dir / getattr(cfg, "checkpoint_name", "best_model_batched_dsp.pt")
    best_test_loss = float("inf")

    ema_beta = 0.9
    ema_train_loss = None
    ema_test_loss = None

    env.set_mode("train")
    global_step = 0

    try:
        for epoch in range(epochs):
            env.set_mode("train")
            obs = env.reset()
            epoch_losses: List[float] = []
            epoch_success = 0
            epoch_total = 0

            for _ in range(updates):
                val_buf: List[torch.Tensor] = []
                logp_buf: List[torch.Tensor] = []
                rew_buf: List[torch.Tensor] = []

                for _ in range(steps_per_epoch):
                    model_obs = build_stft_observation_fast(
                        iq1=obs["iq1"],
                        iq2=obs["iq2"],
                        iq3=obs["iq3"],
                        intake_sample_rate_hz=float(env.jammer_sampling_freq),
                        device=device,
                    )
                    action_t, value_t, logp_t = policy.get_action_value_logp(model_obs)
                    actions = action_t.squeeze()

                    if env.num_envs == 1 and isinstance(actions, torch.Tensor) and actions.ndim >= 1:
                        action_batch = [actions]
                    else:
                        action_batch = actions

                    if not getattr(env, "_active", None):
                        env._active = env._next_samples()
                    active_samples = list(env._active)

                    jam_batch = jammer_controller_batch(
                        model=env.model,
                        samples=active_samples,
                        actions=action_batch,
                        jammer_sampling_freq=env.jammer_sampling_freq,
                        user_peak_power_fraction=env.user_peak_power_fraction,
                        device=env.device,
                    )

                    rewards_t, success, total = compute_rewards_scheduled_batched(
                        jam_batch=jam_batch,
                        samples=active_samples,
                        jammer_sampling_freq=float(env.jammer_sampling_freq),
                        device=device,
                        step_idx=global_step,
                        sched=reward_sched,
                    )
                    epoch_success += int(success)
                    epoch_total += int(total)

                    env._step_count += 1
                    done = env._step_count >= env.max_steps
                    if done:
                        env._active = env._next_samples()
                        env._step_count = 0
                    obs = env._obs_from_samples(env._active)

                    val_buf.append(value_t)
                    logp_buf.append(logp_t)
                    rew_buf.append(rewards_t.to(device=device, dtype=torch.float32))
                    global_step += 1

                returns = torch.stack(rew_buf, dim=0)
                values = torch.stack(val_buf, dim=0)
                logps = torch.stack(logp_buf, dim=0)
                #print(f"logps.mean() : {logps.mean()}")
                if logps.ndim > returns.ndim:
                    logps = logps.squeeze(-1)
                if values.ndim > returns.ndim:
                    values = values.squeeze(-1)

                adv = returns - values.detach()
                adv = adv / (returns.std(unbiased=False) + 1)
                # print(f"logps.mean() : {logps.mean()}")
                # print(f"adv.mean() : {adv.mean()}")

                policy_loss = -(logps * adv.detach()).mean()
                critic_loss = torch.nn.functional.mse_loss(values, returns)
                loss = policy_loss + value_coef * critic_loss

                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                optimizer.step()

                epoch_losses.append(float(loss.item()))

            train_loss_epoch = float(np.mean(epoch_losses)) if epoch_losses else 0.0
            train_decode_pct = (100.0 * epoch_success / epoch_total) if epoch_total else 0.0
            test_loss, test_decode_pct = _evaluate_split_metrics_batched_dsp(
                policy=policy,
                env=env,
                split="test",
                device=device,
                value_coef=value_coef,
                reward_sched=reward_sched,
            )

            ema_train_loss = train_loss_epoch if ema_train_loss is None else (ema_beta * ema_train_loss + (1.0 - ema_beta) * train_loss_epoch)
            ema_test_loss = test_loss if ema_test_loss is None else (ema_beta * ema_test_loss + (1.0 - ema_beta) * test_loss)

            writer.add_scalar("train/loss_epoch", train_loss_epoch, epoch)
            writer.add_scalar("train/loss_ema", ema_train_loss, epoch)
            writer.add_scalar("test/loss_epoch", test_loss, epoch)
            writer.add_scalar("test/loss_ema", ema_test_loss, epoch)
            writer.add_scalar("train/decode_success_pct", train_decode_pct, epoch)
            writer.add_scalar("test/decode_success_pct", test_decode_pct, epoch)

            if test_loss < best_test_loss:
                best_test_loss = test_loss
                torch.save(
                    {
                        "epoch": epoch,
                        "model_state_dict": policy.state_dict(),
                        "optimizer_state_dict": optimizer.state_dict(),
                        "train_loss_epoch": train_loss_epoch,
                        "test_loss_epoch": test_loss,
                        "train_decode_success_pct": train_decode_pct,
                        "test_decode_success_pct": test_decode_pct,
                        "global_step": global_step,
                        "reward_schedule": {
                            "decode_every_n_steps": int(reward_sched.decode_every_n_steps),
                            "proxy_reward_scale": float(reward_sched.proxy_reward_scale),
                        },
                    },
                    best_checkpoint_path,
                )

            print(
                f"epoch={epoch + 1}/{epochs} "
                f"steps_per_epoch={steps_per_epoch} "
                f"train_loss={train_loss_epoch:.4f} "
                f"test_loss={test_loss:.4f} "
                f"train_decode_success_pct={train_decode_pct:.2f} "
                f"test_decode_success_pct={test_decode_pct:.2f}"
            )
    finally:
        writer.close()

    return policy


# Example:
# policy = train_rl_loop_batched_dsp(policy, env, cfg, RewardScheduleConfig(decode_every_n_steps=4))

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# epochs = 250
batch_size = 250
jammer_sampling_freq = 2e9

train_path_dat = Path("C:/Users/theon/Jamming/train_set_00/dataset")
test_path_dat = Path("C:/Users/theon/Jamming/test_set_00/dataset")
checkpoint_dir = Path("checkpoints_accelerated")
checkpoint_dir.mkdir(parents=True, exist_ok=True)

# 1) One-time deterministic precompute/cache of whole_iq + resampled iq1/iq2/iq3.
train_cache_dir = checkpoint_dir / "train_cache"
test_cache_dir = checkpoint_dir / "test_cache"
precompute_training_cache(train_path_dat, train_cache_dir, jammer_sampling_freq, section_len=1024, overwrite=False)
precompute_training_cache(test_path_dat, test_cache_dir, jammer_sampling_freq, section_len=1024, overwrite=False)

# 2) DataLoader path with worker prefetch + pinned memory.
num_workers = 0 if os.name == "nt" else 4
pin_memory = (device == "cuda")


train_loader = create_cached_dataloader(
    train_cache_dir,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
    pin_memory=pin_memory,
    prefetch_factor=2,
    persistent_workers=(num_workers > 0),
)
test_loader = create_cached_dataloader(
    test_cache_dir,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=pin_memory,
    prefetch_factor=2,
    persistent_workers=(num_workers > 0),
)

# %%
@dataclass
class PPOConfig:
    rollout_steps: int = 0 #28
    updates: int = 50#1#00
    epochs: int = 200
    gamma: float = 0.99
    lr: float = 5e-4
    value_coef: float = 0.5
    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    tensorboard_log_dir: str = "runs/train_rl_loop_18"
    checkpoint_dir: str = "checkpoints_rl_18"
    checkpoint_name: str = "best_model_18.pt"

# %%
max_tones = 128
action_dim = 9 + 3*max_tones



ac = ActorCritic(
        action_dim = action_dim,
        in_ch = 14,
        base_ch = 24,
        max_tones = 128,
    ).to("cuda" if torch.cuda.is_available() else "cpu")

jve = JammerVecEnv(
        samples = train_loader,
        test_samples = test_loader,
        model = ac,
        jammer_sampling_freq = float(jammer_sampling_freq),
        num_envs = 1,
        reward_fn = None,
        user_peak_power_fraction= 20.0,
        max_steps = 1,
        device = device)

cfg = PPOConfig()

cfg.rollout_steps = jve._source_batches_per_epoch
test_no = 37

cfg.tensorboard_log_dir = f"runs/train_rl_loop_{test_no}"
cfg.checkpoint_dir = f"checkpoints_rl_{test_no}"
cfg.checkpoint_name = f"best_model_{test_no}.pt"
cfg.value_coef = 0.5
cfg.epochs = 200

rsc = RewardScheduleConfig()

rsc.decode_every_n_steps = 1

p = train_rl_loop_batched_dsp(
    policy = jve.model,
    env = jve,
    cfg = cfg,
    reward_sched = rsc)


p
# Out:
# epoch=1/200 steps_per_epoch=2 train_loss=-3.7849 test_loss=6.0324 train_decode_success_pct=60.00 test_decode_success_pct=50.00
# epoch=2/200 steps_per_epoch=2 train_loss=-0.5531 test_loss=0.4035 train_decode_success_pct=70.00 test_decode_success_pct=100.00
# epoch=3/200 steps_per_epoch=2 train_loss=0.0860 test_loss=-2.9367 train_decode_success_pct=61.00 test_decode_success_pct=50.00
# epoch=4/200 steps_per_epoch=2 train_loss=0.4079 test_loss=-0.5448 train_decode_success_pct=52.00 test_decode_success_pct=100.00
# epoch=5/200 steps_per_epoch=2 train_loss=0.2689 test_loss=8.3027 train_decode_success_pct=64.00 test_decode_success_pct=50.00
# epoch=6/200 steps_per_epoch=2 train_loss=0.0787 test_loss=0.4237 train_decode_success_pct=60.00 test_decode_success_pct=100.00
# epoch=7/200 steps_per_epoch=2 train_loss=-0.2280 test_loss=-1.0371 train_decode_success_pct=69.00 test_decode_success_pct=50.00
# epoch=8/200 steps_per_epoch=2 train_loss=0.2134 test_loss=-6.5588 train_decode_success_pct=58.00 test_decode_success_pct=0.00
# epoch=9/200 steps_per_epoch=2 train_loss=-0.1398 test_loss=0.3176 train_decode_success_pct=54.00 test_decode_success_pct=50.00
# epoch=10/200 steps_per_epoch=2 train_loss=0.5004 test_loss=3.1886 train_decode_success_pct=65.00 test_decode_success_pct=50.00
# epoch=11/200 steps_per_epoch=2 train_loss=0.2443 test_loss=-0.1102 train_decode_success_pct=62.00 test_decode_success_pct=100.00
# epoch=12/200 steps_per_epoch=2 train_loss=-0.1730 test_loss=5.9017 train_decode_success_pct=67.00 test_decode_success_pct=0.00
# epoch=13/200 steps_per_epoch=2 train_loss=0.3843 test_loss=-0.8771 train_decode_success_pct=60.00 test_decode_success_pct=100.00
# epoch=14/200 steps_per_epoch=2 train_loss=-0.6156 test_loss=-0.6289 train_decode_success_pct=52.00 test_decode_success_pct=100.00
# epoch=15/200 steps_per_epoch=2 train_loss=0.2693 test_loss=0.7653 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=16/200 steps_per_epoch=2 train_loss=0.3604 test_loss=21.3895 train_decode_success_pct=62.00 test_decode_success_pct=0.00
# epoch=17/200 steps_per_epoch=2 train_loss=-0.1513 test_loss=-5.4355 train_decode_success_pct=66.00 test_decode_success_pct=50.00
# epoch=18/200 steps_per_epoch=2 train_loss=0.3397 test_loss=-1.3761 train_decode_success_pct=59.00 test_decode_success_pct=100.00
# epoch=19/200 steps_per_epoch=2 train_loss=0.7494 test_loss=-1.6131 train_decode_success_pct=53.00 test_decode_success_pct=100.00
# epoch=20/200 steps_per_epoch=2 train_loss=-0.3654 test_loss=-0.3142 train_decode_success_pct=63.00 test_decode_success_pct=100.00
# epoch=21/200 steps_per_epoch=2 train_loss=-0.0821 test_loss=-1.3764 train_decode_success_pct=61.00 test_decode_success_pct=50.00
# epoch=22/200 steps_per_epoch=2 train_loss=0.4681 test_loss=-9.0544 train_decode_success_pct=67.00 test_decode_success_pct=50.00
# epoch=23/200 steps_per_epoch=2 train_loss=-0.2308 test_loss=-0.1759 train_decode_success_pct=58.00 test_decode_success_pct=100.00
# epoch=24/200 steps_per_epoch=2 train_loss=0.3204 test_loss=1.7875 train_decode_success_pct=55.00 test_decode_success_pct=50.00
# epoch=25/200 steps_per_epoch=2 train_loss=0.6029 test_loss=-2.7905 train_decode_success_pct=58.00 test_decode_success_pct=100.00
# epoch=26/200 steps_per_epoch=2 train_loss=0.1531 test_loss=-5.5404 train_decode_success_pct=59.00 test_decode_success_pct=0.00
# epoch=27/200 steps_per_epoch=2 train_loss=-3.1273 test_loss=24.4469 train_decode_success_pct=64.00 test_decode_success_pct=50.00
# epoch=28/200 steps_per_epoch=2 train_loss=2.0008 test_loss=31.5008 train_decode_success_pct=54.00 test_decode_success_pct=50.00
# epoch=29/200 steps_per_epoch=2 train_loss=1.9974 test_loss=-1.0294 train_decode_success_pct=54.00 test_decode_success_pct=50.00
# epoch=30/200 steps_per_epoch=2 train_loss=0.0202 test_loss=-8.3840 train_decode_success_pct=59.00 test_decode_success_pct=50.00
# epoch=31/200 steps_per_epoch=2 train_loss=-0.6567 test_loss=-3.4388 train_decode_success_pct=60.00 test_decode_success_pct=100.00
# epoch=32/200 steps_per_epoch=2 train_loss=-1.6586 test_loss=3.0287 train_decode_success_pct=64.00 test_decode_success_pct=50.00
# epoch=33/200 steps_per_epoch=2 train_loss=1.3035 test_loss=-5.0844 train_decode_success_pct=53.00 test_decode_success_pct=100.00
# epoch=34/200 steps_per_epoch=2 train_loss=-0.0234 test_loss=-3.6909 train_decode_success_pct=59.00 test_decode_success_pct=100.00
# epoch=35/200 steps_per_epoch=2 train_loss=-0.3782 test_loss=2.0318 train_decode_success_pct=58.00 test_decode_success_pct=50.00
# epoch=36/200 steps_per_epoch=2 train_loss=0.5468 test_loss=-33.5391 train_decode_success_pct=61.00 test_decode_success_pct=0.00
# epoch=37/200 steps_per_epoch=2 train_loss=-0.4217 test_loss=10.7306 train_decode_success_pct=63.00 test_decode_success_pct=50.00
# epoch=38/200 steps_per_epoch=2 train_loss=1.0097 test_loss=-5.0900 train_decode_success_pct=53.00 test_decode_success_pct=50.00
# epoch=39/200 steps_per_epoch=2 train_loss=-1.4567 test_loss=-2.7531 train_decode_success_pct=59.00 test_decode_success_pct=100.00
# epoch=40/200 steps_per_epoch=2 train_loss=-0.3443 test_loss=4.7073 train_decode_success_pct=64.00 test_decode_success_pct=0.00
# epoch=41/200 steps_per_epoch=2 train_loss=-0.1289 test_loss=-5.8043 train_decode_success_pct=59.00 test_decode_success_pct=50.00
# epoch=42/200 steps_per_epoch=2 train_loss=-0.1799 test_loss=-7.4605 train_decode_success_pct=64.00 test_decode_success_pct=50.00
# epoch=43/200 steps_per_epoch=2 train_loss=-0.8128 test_loss=-7.7931 train_decode_success_pct=53.00 test_decode_success_pct=50.00
# epoch=44/200 steps_per_epoch=2 train_loss=-0.4714 test_loss=0.1290 train_decode_success_pct=60.00 test_decode_success_pct=50.00
# epoch=45/200 steps_per_epoch=2 train_loss=1.0057 test_loss=0.0353 train_decode_success_pct=65.00 test_decode_success_pct=100.00
# epoch=46/200 steps_per_epoch=2 train_loss=-0.6866 test_loss=-4.5943 train_decode_success_pct=59.00 test_decode_success_pct=50.00
# epoch=47/200 steps_per_epoch=2 train_loss=0.4285 test_loss=-4.4001 train_decode_success_pct=63.00 test_decode_success_pct=50.00
# epoch=48/200 steps_per_epoch=2 train_loss=-1.2502 test_loss=5.3277 train_decode_success_pct=54.00 test_decode_success_pct=50.00
# epoch=49/200 steps_per_epoch=2 train_loss=0.9007 test_loss=-3.6106 train_decode_success_pct=60.00 test_decode_success_pct=50.00
# epoch=50/200 steps_per_epoch=2 train_loss=-1.0283 test_loss=-1.2413 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=51/200 steps_per_epoch=2 train_loss=-1.2360 test_loss=-12.4576 train_decode_success_pct=58.00 test_decode_success_pct=50.00
# epoch=52/200 steps_per_epoch=2 train_loss=-2.0328 test_loss=-11.5978 train_decode_success_pct=61.00 test_decode_success_pct=50.00
# epoch=53/200 steps_per_epoch=2 train_loss=2.0419 test_loss=3.0503 train_decode_success_pct=54.00 test_decode_success_pct=100.00
# epoch=54/200 steps_per_epoch=2 train_loss=-0.3282 test_loss=-1.2039 train_decode_success_pct=59.00 test_decode_success_pct=50.00
# epoch=55/200 steps_per_epoch=2 train_loss=-1.1500 test_loss=4.3228 train_decode_success_pct=64.00 test_decode_success_pct=50.00
# epoch=56/200 steps_per_epoch=2 train_loss=-1.2505 test_loss=-4.5610 train_decode_success_pct=61.00 test_decode_success_pct=100.00
# epoch=57/200 steps_per_epoch=2 train_loss=-1.1717 test_loss=-4.8149 train_decode_success_pct=58.00 test_decode_success_pct=100.00
# epoch=58/200 steps_per_epoch=2 train_loss=-0.4955 test_loss=-10.6782 train_decode_success_pct=52.00 test_decode_success_pct=50.00
# epoch=59/200 steps_per_epoch=2 train_loss=-11.8387 test_loss=-68.4800 train_decode_success_pct=51.00 test_decode_success_pct=0.00
# epoch=60/200 steps_per_epoch=2 train_loss=-16.8560 test_loss=-105.3813 train_decode_success_pct=45.00 test_decode_success_pct=0.00
# epoch=61/200 steps_per_epoch=2 train_loss=-25.5030 test_loss=0.7189 train_decode_success_pct=42.00 test_decode_success_pct=100.00
# epoch=62/200 steps_per_epoch=2 train_loss=5.2441 test_loss=10.6837 train_decode_success_pct=51.00 test_decode_success_pct=50.00
# epoch=63/200 steps_per_epoch=2 train_loss=7.6146 test_loss=-13.9332 train_decode_success_pct=53.00 test_decode_success_pct=0.00
# epoch=64/200 steps_per_epoch=2 train_loss=19.5781 test_loss=11.8494 train_decode_success_pct=65.00 test_decode_success_pct=100.00
# epoch=65/200 steps_per_epoch=2 train_loss=10.5478 test_loss=338.0456 train_decode_success_pct=64.00 test_decode_success_pct=100.00
# epoch=66/200 steps_per_epoch=2 train_loss=9.3664 test_loss=91.9219 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=67/200 steps_per_epoch=2 train_loss=19.8900 test_loss=161.5757 train_decode_success_pct=61.00 test_decode_success_pct=100.00
# epoch=68/200 steps_per_epoch=2 train_loss=1.0028 test_loss=286.9286 train_decode_success_pct=52.00 test_decode_success_pct=100.00
# epoch=69/200 steps_per_epoch=2 train_loss=23.9414 test_loss=-177.1713 train_decode_success_pct=66.00 test_decode_success_pct=50.00
# epoch=70/200 steps_per_epoch=2 train_loss=9.0357 test_loss=318.0827 train_decode_success_pct=64.00 test_decode_success_pct=100.00
# epoch=71/200 steps_per_epoch=2 train_loss=9.9364 test_loss=17.5431 train_decode_success_pct=65.00 test_decode_success_pct=50.00
# epoch=72/200 steps_per_epoch=2 train_loss=23.5150 test_loss=154.7617 train_decode_success_pct=59.00 test_decode_success_pct=100.00
# epoch=73/200 steps_per_epoch=2 train_loss=5.4720 test_loss=40.4879 train_decode_success_pct=52.00 test_decode_success_pct=50.00
# epoch=74/200 steps_per_epoch=2 train_loss=24.4928 test_loss=-56.2119 train_decode_success_pct=68.00 test_decode_success_pct=100.00
# epoch=75/200 steps_per_epoch=2 train_loss=23.1485 test_loss=257.6672 train_decode_success_pct=64.00 test_decode_success_pct=100.00
# epoch=76/200 steps_per_epoch=2 train_loss=12.4802 test_loss=9.3051 train_decode_success_pct=67.00 test_decode_success_pct=50.00
# epoch=77/200 steps_per_epoch=2 train_loss=13.5937 test_loss=8.9814 train_decode_success_pct=57.00 test_decode_success_pct=50.00
# epoch=78/200 steps_per_epoch=2 train_loss=32.4359 test_loss=32.3936 train_decode_success_pct=56.00 test_decode_success_pct=50.00
# epoch=79/200 steps_per_epoch=2 train_loss=23.5190 test_loss=-93.0963 train_decode_success_pct=66.00 test_decode_success_pct=50.00
# epoch=80/200 steps_per_epoch=2 train_loss=22.6260 test_loss=60.3886 train_decode_success_pct=62.00 test_decode_success_pct=50.00
# epoch=81/200 steps_per_epoch=2 train_loss=22.5325 test_loss=141.4349 train_decode_success_pct=69.00 test_decode_success_pct=100.00
# epoch=82/200 steps_per_epoch=2 train_loss=24.9274 test_loss=47.3115 train_decode_success_pct=58.00 test_decode_success_pct=50.00
# epoch=83/200 steps_per_epoch=2 train_loss=28.8883 test_loss=115.2214 train_decode_success_pct=54.00 test_decode_success_pct=100.00
# epoch=84/200 steps_per_epoch=2 train_loss=12.2740 test_loss=-24.2824 train_decode_success_pct=62.00 test_decode_success_pct=50.00
# epoch=85/200 steps_per_epoch=2 train_loss=12.9958 test_loss=-27.3223 train_decode_success_pct=59.00 test_decode_success_pct=50.00
# epoch=86/200 steps_per_epoch=2 train_loss=6.9600 test_loss=58.1241 train_decode_success_pct=68.00 test_decode_success_pct=100.00
# epoch=87/200 steps_per_epoch=2 train_loss=7.4071 test_loss=-44.8506 train_decode_success_pct=60.00 test_decode_success_pct=0.00
# epoch=88/200 steps_per_epoch=2 train_loss=-0.5291 test_loss=-76.7085 train_decode_success_pct=51.00 test_decode_success_pct=0.00
# epoch=89/200 steps_per_epoch=2 train_loss=4.3246 test_loss=-11.6505 train_decode_success_pct=64.00 test_decode_success_pct=50.00
# epoch=90/200 steps_per_epoch=2 train_loss=1.2703 test_loss=-1.8184 train_decode_success_pct=57.00 test_decode_success_pct=50.00
# epoch=91/200 steps_per_epoch=2 train_loss=1.9752 test_loss=-13.3318 train_decode_success_pct=67.00 test_decode_success_pct=50.00
# epoch=92/200 steps_per_epoch=2 train_loss=1.5760 test_loss=97.5785 train_decode_success_pct=58.00 test_decode_success_pct=100.00
# epoch=93/200 steps_per_epoch=2 train_loss=6.7092 test_loss=18.4210 train_decode_success_pct=51.00 test_decode_success_pct=50.00
# epoch=94/200 steps_per_epoch=2 train_loss=0.2047 test_loss=15.8226 train_decode_success_pct=65.00 test_decode_success_pct=100.00
# epoch=95/200 steps_per_epoch=2 train_loss=4.3387 test_loss=2.8604 train_decode_success_pct=58.00 test_decode_success_pct=50.00
# epoch=96/200 steps_per_epoch=2 train_loss=-2.0790 test_loss=110.5452 train_decode_success_pct=67.00 test_decode_success_pct=100.00
# epoch=97/200 steps_per_epoch=2 train_loss=2.3475 test_loss=-2.0980 train_decode_success_pct=57.00 test_decode_success_pct=50.00
# epoch=98/200 steps_per_epoch=2 train_loss=0.3314 test_loss=4.3227 train_decode_success_pct=52.00 test_decode_success_pct=50.00
# epoch=99/200 steps_per_epoch=2 train_loss=3.8581 test_loss=-115.7406 train_decode_success_pct=62.00 test_decode_success_pct=50.00
# epoch=100/200 steps_per_epoch=2 train_loss=1.4198 test_loss=7.5777 train_decode_success_pct=56.00 test_decode_success_pct=100.00
# epoch=101/200 steps_per_epoch=2 train_loss=0.3200 test_loss=62.5273 train_decode_success_pct=63.00 test_decode_success_pct=100.00
# epoch=102/200 steps_per_epoch=2 train_loss=1.1536 test_loss=60.5551 train_decode_success_pct=53.00 test_decode_success_pct=100.00
# epoch=103/200 steps_per_epoch=2 train_loss=2.0993 test_loss=4.8691 train_decode_success_pct=50.00 test_decode_success_pct=100.00
# epoch=104/200 steps_per_epoch=2 train_loss=0.9425 test_loss=54.4992 train_decode_success_pct=58.00 test_decode_success_pct=100.00
# epoch=105/200 steps_per_epoch=2 train_loss=3.0158 test_loss=31.8254 train_decode_success_pct=58.00 test_decode_success_pct=50.00
# epoch=106/200 steps_per_epoch=2 train_loss=-5.3460 test_loss=54.3320 train_decode_success_pct=61.00 test_decode_success_pct=100.00
# epoch=107/200 steps_per_epoch=2 train_loss=2.6137 test_loss=109.3424 train_decode_success_pct=53.00 test_decode_success_pct=100.00
# epoch=108/200 steps_per_epoch=2 train_loss=-2.9453 test_loss=20.0096 train_decode_success_pct=49.00 test_decode_success_pct=50.00
# epoch=109/200 steps_per_epoch=2 train_loss=6.7459 test_loss=71.8249 train_decode_success_pct=61.00 test_decode_success_pct=50.00
# epoch=110/200 steps_per_epoch=2 train_loss=1.0671 test_loss=43.8915 train_decode_success_pct=55.00 test_decode_success_pct=50.00
# epoch=111/200 steps_per_epoch=2 train_loss=3.1992 test_loss=-26.2569 train_decode_success_pct=60.00 test_decode_success_pct=50.00
# epoch=112/200 steps_per_epoch=2 train_loss=-1.5828 test_loss=-28.7599 train_decode_success_pct=54.00 test_decode_success_pct=50.00
# epoch=113/200 steps_per_epoch=2 train_loss=-2.2758 test_loss=49.5288 train_decode_success_pct=47.00 test_decode_success_pct=50.00
# epoch=114/200 steps_per_epoch=2 train_loss=3.2150 test_loss=-71.5912 train_decode_success_pct=60.00 test_decode_success_pct=0.00
# epoch=115/200 steps_per_epoch=2 train_loss=7.4513 test_loss=8.0760 train_decode_success_pct=57.00 test_decode_success_pct=0.00
# epoch=116/200 steps_per_epoch=2 train_loss=4.3455 test_loss=30.4425 train_decode_success_pct=60.00 test_decode_success_pct=100.00
# epoch=117/200 steps_per_epoch=2 train_loss=-6.4399 test_loss=16.2929 train_decode_success_pct=51.00 test_decode_success_pct=50.00
# epoch=118/200 steps_per_epoch=2 train_loss=3.4258 test_loss=105.2419 train_decode_success_pct=48.00 test_decode_success_pct=100.00
# epoch=119/200 steps_per_epoch=2 train_loss=8.3928 test_loss=9.3639 train_decode_success_pct=59.00 test_decode_success_pct=100.00
# epoch=120/200 steps_per_epoch=2 train_loss=-0.8886 test_loss=-90.4070 train_decode_success_pct=56.00 test_decode_success_pct=50.00
# epoch=121/200 steps_per_epoch=2 train_loss=-1.1325 test_loss=-11.6185 train_decode_success_pct=55.00 test_decode_success_pct=50.00
# epoch=122/200 steps_per_epoch=2 train_loss=-4.0847 test_loss=-44.7612 train_decode_success_pct=44.00 test_decode_success_pct=0.00
# epoch=123/200 steps_per_epoch=2 train_loss=7.9609 test_loss=2.5299 train_decode_success_pct=49.00 test_decode_success_pct=50.00
# epoch=124/200 steps_per_epoch=2 train_loss=1.8419 test_loss=-399.4998 train_decode_success_pct=56.00 test_decode_success_pct=0.00
# epoch=125/200 steps_per_epoch=2 train_loss=-3.1325 test_loss=-47.6952 train_decode_success_pct=51.00 test_decode_success_pct=50.00
# epoch=126/200 steps_per_epoch=2 train_loss=1.5964 test_loss=-3.2781 train_decode_success_pct=58.00 test_decode_success_pct=100.00
# epoch=127/200 steps_per_epoch=2 train_loss=-4.1242 test_loss=105.5510 train_decode_success_pct=46.00 test_decode_success_pct=100.00
# epoch=128/200 steps_per_epoch=2 train_loss=1.5656 test_loss=40.6116 train_decode_success_pct=49.00 test_decode_success_pct=50.00
# epoch=129/200 steps_per_epoch=2 train_loss=1.2898 test_loss=42.6262 train_decode_success_pct=54.00 test_decode_success_pct=100.00
# epoch=130/200 steps_per_epoch=2 train_loss=2.5089 test_loss=27.6145 train_decode_success_pct=56.00 test_decode_success_pct=50.00
# epoch=131/200 steps_per_epoch=2 train_loss=-1.0643 test_loss=-19.1963 train_decode_success_pct=53.00 test_decode_success_pct=50.00
# epoch=132/200 steps_per_epoch=2 train_loss=1.0310 test_loss=44.7814 train_decode_success_pct=47.00 test_decode_success_pct=50.00
# epoch=133/200 steps_per_epoch=2 train_loss=7.5416 test_loss=2.6253 train_decode_success_pct=49.00 test_decode_success_pct=0.00
# epoch=134/200 steps_per_epoch=2 train_loss=-3.0235 test_loss=-10.8654 train_decode_success_pct=55.00 test_decode_success_pct=50.00
# epoch=135/200 steps_per_epoch=2 train_loss=2.7897 test_loss=-81.9187 train_decode_success_pct=53.00 test_decode_success_pct=0.00
# epoch=136/200 steps_per_epoch=2 train_loss=-4.9227 test_loss=41.4863 train_decode_success_pct=54.00 test_decode_success_pct=50.00
# epoch=137/200 steps_per_epoch=2 train_loss=3.7543 test_loss=189.6337 train_decode_success_pct=38.00 test_decode_success_pct=100.00
# epoch=138/200 steps_per_epoch=2 train_loss=-3.8794 test_loss=-21.5639 train_decode_success_pct=55.00 test_decode_success_pct=0.00
# epoch=139/200 steps_per_epoch=2 train_loss=3.4654 test_loss=21.5688 train_decode_success_pct=54.00 test_decode_success_pct=100.00
# epoch=140/200 steps_per_epoch=2 train_loss=-5.9825 test_loss=25.9443 train_decode_success_pct=47.00 test_decode_success_pct=50.00
# epoch=141/200 steps_per_epoch=2 train_loss=7.7125 test_loss=-6.3742 train_decode_success_pct=55.00 test_decode_success_pct=50.00
# epoch=142/200 steps_per_epoch=2 train_loss=0.7377 test_loss=87.0327 train_decode_success_pct=42.00 test_decode_success_pct=100.00
# epoch=143/200 steps_per_epoch=2 train_loss=-0.5911 test_loss=66.7532 train_decode_success_pct=52.00 test_decode_success_pct=50.00
# epoch=144/200 steps_per_epoch=2 train_loss=-5.1474 test_loss=-27.7738 train_decode_success_pct=51.00 test_decode_success_pct=0.00
# epoch=145/200 steps_per_epoch=2 train_loss=-1.4144 test_loss=51.7551 train_decode_success_pct=47.00 test_decode_success_pct=50.00
# epoch=146/200 steps_per_epoch=2 train_loss=10.1910 test_loss=-84.8631 train_decode_success_pct=54.00 test_decode_success_pct=50.00
# epoch=147/200 steps_per_epoch=2 train_loss=-3.3495 test_loss=-9.1229 train_decode_success_pct=40.00 test_decode_success_pct=50.00
# epoch=148/200 steps_per_epoch=2 train_loss=0.8539 test_loss=-306.0851 train_decode_success_pct=49.00 test_decode_success_pct=0.00
# epoch=149/200 steps_per_epoch=2 train_loss=-2.2256 test_loss=61.1341 train_decode_success_pct=52.00 test_decode_success_pct=50.00
# epoch=150/200 steps_per_epoch=2 train_loss=-3.9093 test_loss=86.1519 train_decode_success_pct=43.00 test_decode_success_pct=50.00
# epoch=151/200 steps_per_epoch=2 train_loss=0.4993 test_loss=-12.4658 train_decode_success_pct=50.00 test_decode_success_pct=50.00
# epoch=152/200 steps_per_epoch=2 train_loss=2.0244 test_loss=3.0419 train_decode_success_pct=39.00 test_decode_success_pct=50.00
# epoch=153/200 steps_per_epoch=2 train_loss=-1.2825 test_loss=-45.7380 train_decode_success_pct=47.00 test_decode_success_pct=0.00
# epoch=154/200 steps_per_epoch=2 train_loss=-1.1863 test_loss=5.4627 train_decode_success_pct=51.00 test_decode_success_pct=50.00
# epoch=155/200 steps_per_epoch=2 train_loss=0.9496 test_loss=16.9701 train_decode_success_pct=48.00 test_decode_success_pct=0.00
# epoch=156/200 steps_per_epoch=2 train_loss=-1.6107 test_loss=-20.1051 train_decode_success_pct=47.00 test_decode_success_pct=50.00
# epoch=157/200 steps_per_epoch=2 train_loss=-2.1379 test_loss=69.0659 train_decode_success_pct=36.00 test_decode_success_pct=50.00
# epoch=158/200 steps_per_epoch=2 train_loss=0.3745 test_loss=-7.9962 train_decode_success_pct=52.00 test_decode_success_pct=0.00
# epoch=159/200 steps_per_epoch=2 train_loss=3.9958 test_loss=-7.3666 train_decode_success_pct=52.00 test_decode_success_pct=50.00
# epoch=160/200 steps_per_epoch=2 train_loss=0.0975 test_loss=5.7871 train_decode_success_pct=52.00 test_decode_success_pct=100.00
# epoch=161/200 steps_per_epoch=2 train_loss=-9.8921 test_loss=-51.5529 train_decode_success_pct=44.00 test_decode_success_pct=50.00
# epoch=162/200 steps_per_epoch=2 train_loss=-0.5312 test_loss=-10.5775 train_decode_success_pct=36.00 test_decode_success_pct=50.00
# epoch=163/200 steps_per_epoch=2 train_loss=-3.1854 test_loss=39.1320 train_decode_success_pct=51.00 test_decode_success_pct=0.00
# epoch=164/200 steps_per_epoch=2 train_loss=-2.4496 test_loss=-17.2390 train_decode_success_pct=48.00 test_decode_success_pct=0.00
# epoch=165/200 steps_per_epoch=2 train_loss=5.5873 test_loss=-29.4324 train_decode_success_pct=47.00 test_decode_success_pct=0.00
# epoch=166/200 steps_per_epoch=2 train_loss=-12.1377 test_loss=93.1962 train_decode_success_pct=43.00 test_decode_success_pct=50.00
# epoch=167/200 steps_per_epoch=2 train_loss=9.8150 test_loss=131.4683 train_decode_success_pct=41.00 test_decode_success_pct=100.00
