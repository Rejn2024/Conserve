# %% [markdown]
# # RL Jammer DSP acceleration prototype (`RL_Jammer_testing.ipynb`)
#
# This notebook **implements** (not just documents) DSP-chain accelerations:
# - vectorized/batched STFT feature extraction,
# - cached DSP constants (window/frequency grid),
# - decode scheduling for reward computation,
# - batched decode calls through `rx_command_iq_broadcast`,
# - resample short-circuit when sample rates match.

# %%
from __future__ import annotations

from dataclasses import dataclass
from typing import Any, Dict, List, Sequence, Tuple
import numpy as np
import torch
from pathlib import Path
import os
import advanced_link_skdsp_v7_robust as link7
import score_iq_decode as scorer

from accelerated_training_utils import repeat_to_length_mod

if not hasattr(np, "bool8"):
    np.bool8 = np.bool_

from torch.utils.tensorboard import SummaryWriter

from accelerated_training_utils import (JammerVecEnv,
                                        jammer_controller_batch)
from tx_controller_tone_pulse_stft_varlen_7 import ActorCritic

from accelerated_training_utils import (
    precompute_training_cache,
    create_cached_dataloader,
    )

# %%
_DSP_CACHE: Dict[Tuple[str, int, int, float], Dict[str, torch.Tensor]] = {}


def _get_stft_constants(device: torch.device,
                        nfft: int,
                        nperseg: int,
                        sample_rate_hz: float) -> Dict[str, torch.Tensor]:
    key = (str(device), int(nfft), int(nperseg), float(sample_rate_hz))
    cached = _DSP_CACHE.get(key)
    if cached is not None:
        return cached

    window = torch.hann_window(nperseg, dtype=torch.float32, device=device)
    fgrid = torch.fft.fftshift(
        torch.fft.fftfreq(nfft, d=1.0 / max(float(sample_rate_hz), 1.0)).to(device)
    ).to(torch.float32)
    out = {"window": window, "fgrid": fgrid}
    _DSP_CACHE[key] = out
    return out


def preprocess_batched_iq_to_stft_feature_fast(
    iq_batch: torch.Tensor,
    sample_rate_hz: float,
    nperseg: int = 128,
    noverlap: int = 96,
    nfft: int = 128,
    out_channels: int = 14,
) -> Dict[str, torch.Tensor]:
    """Vectorized STFT preprocessing for a complex IQ batch [B, T]."""
    if not torch.is_tensor(iq_batch):
        iq_batch = torch.as_tensor(iq_batch)
    if iq_batch.ndim != 2:
        raise ValueError(f"iq_batch must be [B, T], got {tuple(iq_batch.shape)}")

    x = iq_batch.to(dtype=torch.complex64)
    if x.shape[1] < 8:
        x = torch.nn.functional.pad(x, (0, 8 - x.shape[1]))

    x = x - x.mean(dim=1, keepdim=True)
    scale = torch.median(torch.abs(x), dim=1, keepdim=True).values
    x = x / (scale + 1e-6)

    nperseg_eff = int(min(nperseg, max(8, x.shape[1])))
    noverlap_eff = int(min(noverlap, nperseg_eff - 1))
    hop_length = max(1, nperseg_eff - noverlap_eff)

    const = _get_stft_constants(device=x.device, nfft=nfft, nperseg=nperseg_eff, sample_rate_hz=sample_rate_hz)

    z = torch.stft(
        x,
        n_fft=nfft,
        hop_length=hop_length,
        win_length=nperseg_eff,
        window=const["window"],
        center=False,
        return_complex=True,
    )
    z = torch.fft.fftshift(z, dim=1)

    mag = torch.log1p(torch.abs(z)).to(torch.float32)
    phase = torch.angle(z).to(torch.float32)
    real = z.real.to(torch.float32)
    imag = z.imag.to(torch.float32)
    power = (torch.abs(z) ** 2).to(torch.float32)
    power_log = torch.log1p(power)

    f = const["fgrid"][None, :, None]
    denom = power.sum(dim=1, keepdim=True) + 1e-12
    centroid = (f * power).sum(dim=1, keepdim=True) / denom
    centroid_plane = centroid.repeat(1, mag.shape[1], 1) / max(float(sample_rate_hz), 1.0)

    spread = torch.sqrt((((f - centroid) ** 2) * power).sum(dim=1, keepdim=True) / denom + 1e-12)
    spread_plane = (spread / max(float(sample_rate_hz), 1.0)).repeat(1, mag.shape[1], 1)

    flatness = torch.exp(torch.mean(torch.log(torch.clamp(power, min=1e-12)), dim=1, keepdim=True))
    flatness = flatness / (power.mean(dim=1, keepdim=True) + 1e-12)
    flatness_plane = flatness.repeat(1, mag.shape[1], 1)

    frame_power = power.mean(dim=1, keepdim=True)
    frame_power_norm = frame_power / (frame_power.mean(dim=2, keepdim=True) + 1e-12)
    frame_power_plane = frame_power_norm.repeat(1, mag.shape[1], 1)

    delta_t_mag = torch.diff(mag, dim=2, prepend=mag[:, :, :1])
    delta_f_mag = torch.diff(mag, dim=1, prepend=mag[:, :1, :])
    delta_t_power = torch.diff(power_log, dim=2, prepend=power_log[:, :, :1])
    delta_t_phase = torch.diff(phase, dim=2, prepend=phase[:, :, :1])

    sr_plane = torch.full_like(mag, torch.log10(torch.tensor(max(float(sample_rate_hz), 1.0), device=mag.device)) / 10.0)

    feat = torch.stack(
        [
            mag,
            phase,
            centroid_plane,
            sr_plane,
            real,
            imag,
            power_log,
            delta_t_mag,
            delta_f_mag,
            delta_t_phase,
            delta_t_power,
            spread_plane,
            flatness_plane,
            frame_power_plane,
        ][:out_channels],
        dim=1,
    )

    peak_bin = torch.argmax(power.mean(dim=2), dim=1)
    peak_hz = const["fgrid"][peak_bin]
    rx_power = (x.abs() ** 2).mean(dim=1)

    return {
        "feature": feat.to(torch.float32),
        "rx_power": rx_power.to(torch.float32),
        "peak_hz": peak_hz.to(torch.float32),
        "lengths": torch.full((x.shape[0],), float(x.shape[1]), device=x.device, dtype=torch.float32),
    }

# %%
def build_stft_observation_fast(
    *,
    iq1: torch.Tensor,
    iq2: torch.Tensor,
    iq3: torch.Tensor,
    intake_sample_rate_hz: float,
    device: str = "cpu",
) -> Dict[str, List[torch.Tensor]]:
    p1 = preprocess_batched_iq_to_stft_feature_fast(iq1, intake_sample_rate_hz)
    p2 = preprocess_batched_iq_to_stft_feature_fast(iq2, intake_sample_rate_hz)
    p3 = preprocess_batched_iq_to_stft_feature_fast(iq3, intake_sample_rate_hz)
    return {
        "stft_feature_list": [
            p1["feature"].to(device=device, dtype=torch.float32, non_blocking=True),
            p2["feature"].to(device=device, dtype=torch.float32, non_blocking=True),
            p3["feature"].to(device=device, dtype=torch.float32, non_blocking=True),
        ]
    }

# %%
@dataclass
class RewardScheduleConfig:
    decode_every_n_steps: int = 4
    proxy_reward_scale: float = 0.01


def _batched_decode(iq_batch: torch.Tensor, meta_list: Sequence[Dict[str, Any]]) -> List[Dict[str, Any]]:
    if hasattr(link7, "rx_command_iq_broadcast"):
        return link7.rx_command_iq_broadcast(iq_batch, list(meta_list))
    return [link7.rx_command_iq(iq_batch[i], meta_list[i]) for i in range(iq_batch.shape[0])]


def compute_rewards_scheduled_batched(
    *,
    jam_batch: Sequence[Dict[str, Any]],
    samples: Sequence[Dict[str, Any]],
    jammer_sampling_freq: float,
    device: str,
    step_idx: int,
    sched: RewardScheduleConfig,
) -> Tuple[torch.Tensor, int, int]:
    """Batched reward computation with decode scheduling + resample short-circuit."""
    dev = torch.device(device)
    # do_decode = (step_idx % max(1, int(sched.decode_every_n_steps)) == 0)

    jammed_rows: List[torch.Tensor] = []
    metas: List[Dict[str, Any]] = []
    proxy_rewards: List[torch.Tensor] = []

    for jam_item, sample in zip(jam_batch, samples):
        tx_iq = jam_item["tx_iq"].to(dtype=torch.complex64)
        whole_iq = sample["whole_iq"].to(dtype=torch.complex64)
        whole_meta = sample["whole_meta"]
        sr_out = float(whole_meta["sample_rate_hz"])

        if abs(float(jammer_sampling_freq) - sr_out) < 1e-6:
            tx_rs = tx_iq
        else:
            tx_rs = link7.resample_iq(tx_iq, fs_in_hz=float(jammer_sampling_freq), fs_out_hz=sr_out)

        tx_rs = repeat_to_length_mod(tx_rs, int(whole_iq.shape[0]))
        tx_rs = torch.as_tensor(tx_rs[: whole_iq.shape[0]], dtype=torch.complex64)

        jammed = whole_iq.to(device) + tx_rs.to(device)
        jammed_rows.append(jammed.to(dev))
        metas.append(whole_meta)

        # proxy = -sched.proxy_reward_scale * torch.mean(torch.abs(tx_rs) ** 2)
        # proxy_rewards.append(proxy.to(torch.float32))

    if not jammed_rows:
        return torch.zeros(0, dtype=torch.float32, device=dev), 0, 0

    # if not do_decode:
    #     return torch.stack(proxy_rewards).to(device=dev), 0, 0

    max_len = max(int(x.numel()) for x in jammed_rows)
    jammed_pad = [torch.nn.functional.pad(x, (0, max_len - int(x.numel()))) for x in jammed_rows]
    jammed_batch = torch.stack(jammed_pad, dim=0).to(device=dev, dtype=torch.complex64)

    results = _batched_decode(jammed_batch, metas)

    scores: List[torch.Tensor] = []
    decoded = 0
    total = 0
    for r, m in zip(results, metas):
        total += 1
        s = float(
            scorer.score_decode(r, m)) if r is not None else 1.0
        if s < 1.0:
            decoded += 1
        scores.append(torch.tensor(s, dtype=torch.float32, device=dev))

    return torch.stack(scores), decoded, total

# %%
def _resolve_steps_per_epoch_for_notebook(env: JammerVecEnv, rollout_steps: int = 0) -> int:
    if int(rollout_steps) > 0:
        return int(rollout_steps)
    if hasattr(env, "_source_batches_per_epoch") and int(getattr(env, "_source_batches_per_epoch", 0)) > 0:
        return int(env._source_batches_per_epoch)
    sample_count = len(getattr(env, "samples", []))
    return max(1, int(np.ceil(sample_count / max(1, int(env.num_envs)))))


@torch.no_grad()
def _evaluate_split_metrics_batched_dsp(
    policy: torch.nn.Module,
    env: JammerVecEnv,
    split: str,
    device: str,
    value_coef: float,
    reward_sched: RewardScheduleConfig,
) -> Tuple[float, float]:
    split_samples = getattr(env, "test_samples", None) if split == "test" else getattr(env, "samples", None)
    if not split_samples:
        return float("inf"), 0.0

    logp_buf: List[torch.Tensor] = []
    rew_buf: List[torch.Tensor] = []
    val_buf: List[torch.Tensor] = []
    decodes = 0
    decode_total = 0
    eval_step_idx = 0

    original_mode = env.mode
    original_active = list(getattr(env, "_active", []))
    original_step_count = int(getattr(env, "_step_count", 0))

    try:
        env.set_mode(split)
        obs = env.reset()
        eval_steps = _resolve_steps_per_epoch_for_notebook(env, 0)

        for _ in range(eval_steps):
            model_obs = build_stft_observation_fast(
                iq1=obs["iq1"],
                iq2=obs["iq2"],
                iq3=obs["iq3"],
                intake_sample_rate_hz=float(env.jammer_sampling_freq),
                device=device,
            )
            action_t, value_t, logp_t = policy.get_action_value_logp(model_obs)
            actions = action_t.squeeze()
            if env.num_envs == 1 and isinstance(actions, torch.Tensor) and actions.ndim >= 1:
                action_batch = [actions]
            else:
                action_batch = actions

            if not getattr(env, "_active", None):
                env._active = env._next_samples()
            active_samples = list(env._active)

            jam_batch = jammer_controller_batch(
                model=env.model,
                samples=active_samples,
                actions=action_batch,
                jammer_sampling_freq=env.jammer_sampling_freq,
                user_peak_power_fraction=env.user_peak_power_fraction,
                device=env.device,
            )

            rewards_t, decode, total = compute_rewards_scheduled_batched(
                jam_batch=jam_batch,
                samples=active_samples,
                jammer_sampling_freq=float(env.jammer_sampling_freq),
                device=device,
                step_idx=eval_step_idx,
                sched=reward_sched,
            )
            eval_step_idx += 1
            decodes += int(decode)
            decode_total += int(total)

            env._step_count += 1
            done = env._step_count >= env.max_steps
            if done:
                env._active = env._next_samples()
                env._step_count = 0
            obs = env._obs_from_samples(env._active)

            logp_buf.append(logp_t)
            val_buf.append(value_t)
            rew_buf.append(rewards_t.to(device=device, dtype=torch.float32))

        returns = torch.stack(rew_buf, dim=0)
        values = torch.stack(val_buf, dim=0)
        logps = torch.stack(logp_buf, dim=0)
        if logps.ndim > returns.ndim:
            logps = logps.squeeze(-1)
        if values.ndim > returns.ndim:
            values = values.squeeze(-1)

        adv =  returns  #- values.detach()
        # adv = adv / (returns.std(unbiased=False) + 1)
        policy_loss = -(logps * adv.detach()).mean()
        # critic_loss = torch.nn.functional.mse_loss(values, returns)
        loss = policy_loss #+ value_coef * critic_loss
        # print(f" test logps.mean() : {logps.mean()}")
        # print(f" test adv.mean() : {adv.mean()}")

        decode_pct = (100.0 * decodes / decode_total) if decode_total else 0.0

        return float(loss.item()), float(decode_pct)
    finally:
        env.set_mode(original_mode)
        env._active = original_active
        env._step_count = original_step_count


def train_rl_loop_batched_dsp(
    policy: torch.nn.Module,
    env: JammerVecEnv,
    cfg: Any,
    reward_sched: RewardScheduleConfig,
):
    """PPO-style RL loop that uses one JammerVecEnv for train/test, epoch-wise eval, and checkpointing."""
    device = getattr(cfg, "device", "cuda" if torch.cuda.is_available() else "cpu")
    lr = float(getattr(cfg, "lr", 3e-4))
    epochs = max(1, int(getattr(cfg, "epochs", 1)))
    updates = max(1, int(getattr(cfg, "updates", 1)))
    value_coef = float(getattr(cfg, "value_coef", 0.5))
    rollout_steps = int(getattr(cfg, "rollout_steps", 0))

    optimizer = torch.optim.Adam(policy.parameters(), lr=lr)
    steps_per_epoch = _resolve_steps_per_epoch_for_notebook(env, rollout_steps)

    writer = SummaryWriter(log_dir=getattr(cfg, "tensorboard_log_dir", "runs/train_rl_loop_batched_dsp"))
    checkpoint_dir = Path(getattr(cfg, "checkpoint_dir", "checkpoints_rl_batched_dsp"))
    checkpoint_dir.mkdir(parents=True, exist_ok=True)
    best_checkpoint_path = checkpoint_dir / getattr(cfg, "checkpoint_name", "best_model_batched_dsp.pt")
    best_test_loss = float("inf")

    ema_beta = 0.9
    ema_train_loss = None
    ema_test_loss = None

    env.set_mode("train")
    obs = env.reset()
    global_step = 0

    try:
        for epoch in range(epochs):
            env.set_mode("train")
            obs = env.reset()
            epoch_losses: List[float] = []
            epoch_decodes = 0
            epoch_total = 0

            for _ in range(updates):
                val_buf: List[torch.Tensor] = []
                logp_buf: List[torch.Tensor] = []
                rew_buf: List[torch.Tensor] = []

                for _ in range(steps_per_epoch):
                    model_obs = build_stft_observation_fast(
                        iq1=obs["iq1"],
                        iq2=obs["iq2"],
                        iq3=obs["iq3"],
                        intake_sample_rate_hz=float(env.jammer_sampling_freq),
                        device=device,
                    )
                    action_t, value_t, logp_t = policy.get_action_value_logp(model_obs)
                    actions = action_t.squeeze()

                    if env.num_envs == 1 and isinstance(actions, torch.Tensor) and actions.ndim >= 1:
                        action_batch = [actions]
                    else:
                        action_batch = actions

                    if not getattr(env, "_active", None):
                        env._active = env._next_samples()
                    active_samples = list(env._active)

                    jam_batch = jammer_controller_batch(
                        model=env.model,
                        samples=active_samples,
                        actions=action_batch,
                        jammer_sampling_freq=env.jammer_sampling_freq,
                        user_peak_power_fraction=env.user_peak_power_fraction,
                        device=env.device,
                    )

                    rewards_t, decode, total = compute_rewards_scheduled_batched(
                        jam_batch=jam_batch,
                        samples=active_samples,
                        jammer_sampling_freq=float(env.jammer_sampling_freq),
                        device=device,
                        step_idx=global_step,
                        sched=reward_sched,
                    )
                    epoch_decodes += int(decode)
                    epoch_total += int(total)

                    env._step_count += 1
                    done = env._step_count >= env.max_steps
                    if done:
                        env._active = env._next_samples()
                        env._step_count = 0
                    obs = env._obs_from_samples(env._active)

                    val_buf.append(value_t)
                    logp_buf.append(logp_t)
                    rew_buf.append(rewards_t.to(device=device, dtype=torch.float32))
                    global_step += 1

                returns = torch.stack(rew_buf, dim=0)
                values = torch.stack(val_buf, dim=0)
                logps = torch.stack(logp_buf, dim=0)
                #print(f"logps.mean() : {logps.mean()}")
                if logps.ndim > returns.ndim:
                    logps = logps.squeeze(-1)
                if values.ndim > returns.ndim:
                    values = values.squeeze(-1)

                adv = returns #- values.detach()
                # adv = adv / (returns.std(unbiased=False) + 1)
                # print(f"logps.mean() : {logps.mean()}")
                # print(f"adv.mean() : {adv.mean()}")

                policy_loss = -(logps * adv.detach()).mean()
                # critic_loss = torch.nn.functional.mse_loss(values, returns)
                loss = policy_loss # + value_coef * critic_loss

                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                optimizer.step()

                epoch_losses.append(float(loss.item()))

            train_loss_epoch = float(np.mean(epoch_losses)) if epoch_losses else 0.0
            train_decode_pct = (100.0 * epoch_decodes / epoch_total) if epoch_total else 0.0
            test_loss, test_decode_pct = _evaluate_split_metrics_batched_dsp(
                policy=policy,
                env=env,
                split="test",
                device=device,
                value_coef=value_coef,
                reward_sched=reward_sched,
            )

            ema_train_loss = train_loss_epoch if ema_train_loss is None else (ema_beta * ema_train_loss + (1.0 - ema_beta) * train_loss_epoch)
            ema_test_loss = test_loss if ema_test_loss is None else (ema_beta * ema_test_loss + (1.0 - ema_beta) * test_loss)

            writer.add_scalar("train/loss_epoch", train_loss_epoch, epoch)
            writer.add_scalar("train/loss_ema", ema_train_loss, epoch)
            writer.add_scalar("test/loss_epoch", test_loss, epoch)
            writer.add_scalar("test/loss_ema", ema_test_loss, epoch)
            writer.add_scalar("train/decoded_pct", train_decode_pct, epoch)
            writer.add_scalar("test/decoded_pct", test_decode_pct, epoch)

            if test_loss < best_test_loss:
                best_test_loss = test_loss
                torch.save(
                    {
                        "epoch": epoch,
                        "model_state_dict": policy.state_dict(),
                        "optimizer_state_dict": optimizer.state_dict(),
                        "train_loss_epoch": train_loss_epoch,
                        "test_loss_epoch": test_loss,
                        "train_decoded_pct": train_decode_pct,
                        "test_decoded_pct": test_decode_pct,
                        "global_step": global_step,
                        "reward_schedule": {
                            "decode_every_n_steps": int(reward_sched.decode_every_n_steps),
                            "proxy_reward_scale": float(reward_sched.proxy_reward_scale),
                        },
                    },
                    best_checkpoint_path,
                )

            print(
                f"epoch={epoch + 1}/{epochs} "
                f"steps_per_epoch={steps_per_epoch} "
                f"train_loss={train_loss_epoch:.4f} "
                f"test_loss={test_loss:.4f} "
                f"train_decoded_pct={train_decode_pct:.2f} "
                f"test_decoded_pct={test_decode_pct:.2f}"
            )
    finally:
        writer.close()

    return policy


# Example:
# policy = train_rl_loop_batched_dsp(policy, env, cfg, RewardScheduleConfig(decode_every_n_steps=4))

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# epochs = 250
# batch_size = 250
jammer_sampling_freq = 2e9

train_path_dat = Path("C:/Users/theon/Jamming/train_set_00/dataset")
test_path_dat = Path("C:/Users/theon/Jamming/test_set_00/dataset")
checkpoint_dir = Path("checkpoints_accelerated")
checkpoint_dir.mkdir(parents=True, exist_ok=True)

# 1) One-time deterministic precompute/cache of whole_iq + resampled iq1/iq2/iq3.
train_cache_dir = checkpoint_dir / "train_cache"
test_cache_dir = checkpoint_dir / "test_cache"
precompute_training_cache(train_path_dat, train_cache_dir, jammer_sampling_freq, section_len=1024, overwrite=False)
precompute_training_cache(test_path_dat, test_cache_dir, jammer_sampling_freq, section_len=1024, overwrite=False)

# 2) DataLoader path with worker prefetch + pinned memory.
num_workers = 0 if os.name == "nt" else 4
pin_memory = (device == "cuda")

batch_size = 500
train_loader = create_cached_dataloader(
    train_cache_dir,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
    pin_memory=pin_memory,
    prefetch_factor=2,
    persistent_workers=(num_workers > 0),
)
test_loader = create_cached_dataloader(
    test_cache_dir,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=pin_memory,
    prefetch_factor=2,
    persistent_workers=(num_workers > 0),
)

# %%
@dataclass
class PPOConfig:
    rollout_steps: int = 0 #28
    updates: int = 50#1#00
    epochs: int = 200
    gamma: float = 0.99
    lr: float = 5e-4
    value_coef: float = 0.5
    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    tensorboard_log_dir: str = "runs/train_rl_loop_18"
    checkpoint_dir: str = "checkpoints_rl_18"
    checkpoint_name: str = "best_model_18.pt"

# %%
max_tones = 128
max_pulses = 33
action_dim = 10 + 4*max_tones

action_dim = 11+4*max_tones+max_pulses

ac = ActorCritic(
        action_dim = action_dim,
        # in_ch = 14,
        base_ch = 24,
        max_tones = 128,
    ).to("cuda" if torch.cuda.is_available() else "cpu")

jve = JammerVecEnv(
        samples = train_loader,
        test_samples = test_loader,
        model = ac,
        jammer_sampling_freq = float(jammer_sampling_freq),
        num_envs = 1,
        reward_fn = None,
        user_peak_power_fraction= 20.0,
        max_steps = 1,
        device = device)

cfg = PPOConfig()

cfg.rollout_steps = jve._source_batches_per_epoch
test_no = 40

cfg.tensorboard_log_dir = f"runs/train_rl_loop_{test_no}"
cfg.checkpoint_dir = f"checkpoints_rl_{test_no}"
cfg.checkpoint_name = f"best_model_{test_no}.pt"

print(cfg.tensorboard_log_dir, cfg.checkpoint_dir, cfg.checkpoint_name)
cfg.value_coef = 0.5
cfg.epochs = 200

rsc = RewardScheduleConfig()

rsc.decode_every_n_steps = 1

p = train_rl_loop_batched_dsp(
    policy = jve.model,
    env = jve,
    cfg = cfg,
    reward_sched = rsc)


p
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 14
#       5 action_dim = 11+4*max_tones+max_pulses
#       7 ac = ActorCritic(
#       8         action_dim = action_dim,
#       9         # in_ch = 14,
#      10         base_ch = 24,
#      11         max_tones = 128,
#      12     ).to("cuda" if torch.cuda.is_available() else "cpu")
# ---> 14 jve = JammerVecEnv(
#      15         samples = train_loader,
#      16         test_samples = test_loader,
#      17         model = ac,
#      18         jammer_sampling_freq = float(jammer_sampling_freq),
#      19         num_envs = 1,
#      20         reward_fn = None,
#      21         user_peak_power_fraction= 20.0,
#      22         max_steps = 1,
#      23         device = device)
#      25 cfg = PPOConfig()
#      27 cfg.rollout_steps = jve._source_batches_per_epoch
#
# File ~\Jamming\Conserve\accelerated_training_utils.py:527, in JammerVecEnv.__init__(self, samples, test_samples, model, jammer_sampling_freq, num_envs, reward_fn, max_steps, user_peak_power_fraction, device)
#     524 except Exception:
#     525     self._source_batches_per_epoch = 0
# --> 527 self.samples = self._coerce_samples(samples)
#     528 if not self.samples:
#     529     raise ValueError("samples must be non-empty")
#
# File ~\Jamming\Conserve\accelerated_training_utils.py:582, in JammerVecEnv._coerce_samples(cls, samples)
#     579 @classmethod
#     580 def _coerce_samples(cls, samples: Iterable[Dict[str, Any]]) -> List[Dict[str, Any]]:
#     581     materialized: List[Dict[str, Any]] = []
# --> 582     for item in samples:
#     583         if not isinstance(item, dict):
#     584             raise TypeError("samples must contain dict entries or cached batch dicts")
#
# File ~\.conda\envs\jammer\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File ~\.conda\envs\jammer\Lib\site-packages\torch\utils\data\dataloader.py:801, in _SingleProcessDataLoaderIter._next_data(self)
#     799 def _next_data(self):
#     800     index = self._next_index()  # may raise StopIteration
# --> 801     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802     if self._pin_memory:
#     803         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\.conda\envs\jammer\Lib\site-packages\torch\utils\data\_utils\fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
# ---> 54         data = [self.dataset[idx] for idx in possibly_batched_index]
#      55 else:
#      56     data = self.dataset[possibly_batched_index]
#
# File ~\Jamming\Conserve\accelerated_training_utils.py:130, in CachedIQDataset.__getitem__(self, idx)
#     129 def __getitem__(self, idx: int) -> Dict[str, Any]:
# --> 130     return torch.load(self.records[idx],
#     131                       map_location="cpu",
#     132                       weights_only=False)
#
# File ~\.conda\envs\jammer\Lib\site-packages\torch\serialization.py:1579, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1577             except pickle.UnpicklingError as e:
#    1578                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1579         return _load(
#    1580             opened_zipfile,
#    1581             map_location,
#    1582             pickle_module,
#    1583             overall_storage=overall_storage,
#    1584             **pickle_load_args,
#    1585         )
#    1586 if mmap:
#    1587     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File ~\.conda\envs\jammer\Lib\site-packages\torch\serialization.py:2190, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    2188 global _serialization_tls
#    2189 _serialization_tls.map_location = map_location
# -> 2190 result = unpickler.load()
#    2191 _serialization_tls.map_location = None
#    2193 torch._utils._validate_loaded_sparse_tensors()
#
# File ~\.conda\envs\jammer\Lib\site-packages\torch\_utils.py:236, in _rebuild_tensor_v2(storage, storage_offset, size, stride, requires_grad, backward_hooks, metadata)
#     227 def _rebuild_tensor_v2(
#     228     storage,
#     229     storage_offset,
#    (...)    234     metadata=None,
#     235 ):
# --> 236     tensor = _rebuild_tensor(storage, storage_offset, size, stride)
#     237     tensor.requires_grad = requires_grad
#     238     if metadata:
#
# File ~\.conda\envs\jammer\Lib\site-packages\torch\_utils.py:196, in _rebuild_tensor(storage, storage_offset, size, stride)
#     193 def _rebuild_tensor(storage, storage_offset, size, stride):
#     194     # first construct a tensor with the correct dtype/device
#     195     t = torch.empty((0,), dtype=storage.dtype, device=storage._untyped_storage.device)
# --> 196     return t.set_(storage._untyped_storage, storage_offset, size, stride)
#
# KeyboardInterrupt:

# %%
jve = JammerVecEnv(
        samples = train_loader,
        test_samples = test_loader,
        model = ac,
        jammer_sampling_freq = float(jammer_sampling_freq),
        num_envs = 1,
        reward_fn = None,
        user_peak_power_fraction= 1.0,
        max_steps = 1,
        device = device)

cfg = PPOConfig()

cfg.rollout_steps = jve._source_batches_per_epoch
test_no = 41

cfg.tensorboard_log_dir = f"runs/train_rl_loop_{test_no}"
cfg.checkpoint_dir = f"checkpoints_rl_{test_no}"
cfg.checkpoint_name = f"best_model_{test_no}.pt"

print(cfg.tensorboard_log_dir, cfg.checkpoint_dir, cfg.checkpoint_name)
cfg.value_coef = 0.5
cfg.epochs = 200

rsc = RewardScheduleConfig()

rsc.decode_every_n_steps = 1

p = train_rl_loop_batched_dsp(
    policy = jve.model,
    env = jve,
    cfg = cfg,
    reward_sched = rsc)

# %%
jve = JammerVecEnv(
        samples = train_loader,
        test_samples = test_loader,
        model = ac,
        jammer_sampling_freq = float(jammer_sampling_freq),
        num_envs = 1,
        reward_fn = None,
        user_peak_power_fraction= 0.1,
        max_steps = 1,
        device = device)

cfg = PPOConfig()

cfg.rollout_steps = jve._source_batches_per_epoch
test_no = 42

cfg.tensorboard_log_dir = f"runs/train_rl_loop_{test_no}"
cfg.checkpoint_dir = f"checkpoints_rl_{test_no}"
cfg.checkpoint_name = f"best_model_{test_no}.pt"

print(cfg.tensorboard_log_dir, cfg.checkpoint_dir, cfg.checkpoint_name)
cfg.value_coef = 0.5
cfg.epochs = 200

rsc = RewardScheduleConfig()

rsc.decode_every_n_steps = 1

p = train_rl_loop_batched_dsp(
    policy = jve.model,
    env = jve,
    cfg = cfg,
    reward_sched = rsc)

# %%
jve = JammerVecEnv(
        samples = train_loader,
        test_samples = test_loader,
        model = ac,
        jammer_sampling_freq = float(jammer_sampling_freq),
        num_envs = 1,
        reward_fn = None,
        user_peak_power_fraction= 1e-3,
        max_steps = 1,
        device = device)

cfg = PPOConfig()

cfg.rollout_steps = jve._source_batches_per_epoch
test_no = 43

cfg.tensorboard_log_dir = f"runs/train_rl_loop_{test_no}"
cfg.checkpoint_dir = f"checkpoints_rl_{test_no}"
cfg.checkpoint_name = f"best_model_{test_no}.pt"

print(cfg.tensorboard_log_dir, cfg.checkpoint_dir, cfg.checkpoint_name)
cfg.value_coef = 0.5
cfg.epochs = 200

rsc = RewardScheduleConfig()

rsc.decode_every_n_steps = 1

p = train_rl_loop_batched_dsp(
    policy = jve.model,
    env = jve,
    cfg = cfg,
    reward_sched = rsc)

# %%
jve = JammerVecEnv(
        samples = train_loader,
        test_samples = test_loader,
        model = ac,
        jammer_sampling_freq = float(jammer_sampling_freq),
        num_envs = 1,
        reward_fn = None,
        user_peak_power_fraction= 1e-6,
        max_steps = 1,
        device = device)

cfg = PPOConfig()

cfg.rollout_steps = jve._source_batches_per_epoch
test_no = 44

cfg.tensorboard_log_dir = f"runs/train_rl_loop_{test_no}"
cfg.checkpoint_dir = f"checkpoints_rl_{test_no}"
cfg.checkpoint_name = f"best_model_{test_no}.pt"

print(cfg.tensorboard_log_dir, cfg.checkpoint_dir, cfg.checkpoint_name)
cfg.value_coef = 0.5
cfg.epochs = 200

rsc = RewardScheduleConfig()

rsc.decode_every_n_steps = 1

p = train_rl_loop_batched_dsp(
    policy = jve.model,
    env = jve,
    cfg = cfg,
    reward_sched = rsc)
# Out:
# runs/train_rl_loop_44 checkpoints_rl_44 best_model_44.pt
# epoch=1/200 steps_per_epoch=1 train_loss=-263.0926 test_loss=-542.8482 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=2/200 steps_per_epoch=1 train_loss=-537.5509 test_loss=-556.7528 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=3/200 steps_per_epoch=1 train_loss=-535.8415 test_loss=-547.6989 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 29
#      25 rsc = RewardScheduleConfig()
#      27 rsc.decode_every_n_steps = 1
# ---> 29 p = train_rl_loop_batched_dsp(
#      30     policy = jve.model,
#      31     env = jve,
#      32     cfg = cfg,
#      33     reward_sched = rsc)
#
# Cell In[31], line 188, in train_rl_loop_batched_dsp(policy, env, cfg, reward_sched)
#     177 active_samples = list(env._active)
#     179 jam_batch = jammer_controller_batch(
#     180     model=env.model,
#     181     samples=active_samples,
#    (...)    185     device=env.device,
#     186 )
# --> 188 rewards_t, success, total = compute_rewards_scheduled_batched(
#     189     jam_batch=jam_batch,
#     190     samples=active_samples,
#     191     jammer_sampling_freq=float(env.jammer_sampling_freq),
#     192     device=device,
#     193     step_idx=global_step,
#     194     sched=reward_sched,
#     195 )
#     196 epoch_success += int(success)
#     197 epoch_total += int(total)
#
# Cell In[30], line 61, in compute_rewards_scheduled_batched(jam_batch, samples, jammer_sampling_freq, device, step_idx, sched)
#      58 jammed_pad = [torch.nn.functional.pad(x, (0, max_len - int(x.numel()))) for x in jammed_rows]
#      59 jammed_batch = torch.stack(jammed_pad, dim=0).to(device=dev, dtype=torch.complex64)
# ---> 61 results = _batched_decode(jammed_batch, metas)
#      63 scores: List[torch.Tensor] = []
#      64 success = 0
#
# Cell In[30], line 9, in _batched_decode(iq_batch, meta_list)
#       7 def _batched_decode(iq_batch: torch.Tensor, meta_list: Sequence[Dict[str, Any]]) -> List[Dict[str, Any]]:
#       8     if hasattr(link7, "rx_command_iq_broadcast"):
# ----> 9         return link7.rx_command_iq_broadcast(iq_batch, list(meta_list))
#      10     return [link7.rx_command_iq(iq_batch[i], meta_list[i]) for i in range(iq_batch.shape[0])]
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1936, in rx_command_iq_broadcast(iq_batch, meta_list)
#    1933     continue
#    1935 try:
# -> 1936     results.append(rx_command_iq(iq_i, meta_i))
#    1937 except Exception as exc:
#    1938     results.append({
#    1939         "payload_bytes": None,
#    1940         "payload_len": 0,
#    (...)   1946         "error": str(exc),
#    1947     })
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1821, in rx_command_iq(iq, meta)
#    1811 access_ref_waveform = get_cached_access_ref(sps=sps, beta=beta, span=span, device=iq.device)
#    1813 # loop_coarse_start, loop_coarse_cfo_hz, loop_coarse_metric = loop_coarse_frequency_acquire(
#    1814 #     iq=iq,
#    1815 #     ref_waveform=access_ref_waveform,
#    (...)   1818 #     n_bins=coarse_freq_bins,
#    1819 # )
# -> 1821 coarse_start, coarse_cfo_hz, coarse_metric, metric_div = coarse_frequency_acquire(
#    1822     iq=iq,
#    1823     ref_waveform=access_ref_waveform,
#    1824     sample_rate_hz=dsp_sample_rate_hz,
#    1825     search_hz=coarse_freq_search_hz,
#    1826     n_bins=coarse_freq_bins,
#    1827 )
#    1829 # print(f'coarse_start: {coarse_start}, coarse_cfo_hz : {coarse_cfo_hz}, coarse_metric : {coarse_metric}')
#    1831 iq = apply_carrier_frequency(iq, carrier_hz=-coarse_cfo_hz, sample_rate_hz=dsp_sample_rate_hz)
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1333, in coarse_frequency_acquire(iq, ref_waveform, sample_rate_hz, search_hz, n_bins, coarse_bins, chunk_bins)
#    1330 fine_high = min(search_hz, coarse_cfo + fine_half_span)
#    1331 fine_grid = torch.linspace(fine_low, fine_high, int(n_bins), dtype=torch.float64, device=x.device)
# -> 1333 best_start, best_cfo, best_metric, fine_scores = _scan_bins(fine_grid)
#    1335 scores = torch.cat([coarse_scores.to(torch.float32), fine_scores.to(torch.float32)])
#    1336 std = torch.std(scores).clamp_min(1e-6)
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1313, in coarse_frequency_acquire.<locals>._scan_bins(bins)
#    1311 metrics, idxs = torch.max(mag, dim=1)
#    1312 per_bin_scores.append(metrics)
# -> 1313 local_best = int(torch.argmax(metrics).item())
#    1314 local_metric = float(metrics[local_best].item())
#    1315 if local_metric > best_metric_local:
#
# KeyboardInterrupt:

# %%
max_tones = 128
max_pulses = 33
action_dim = 10 + 4*max_tones

action_dim = 11+4*max_tones+max_pulses

ac = ActorCritic(
        action_dim = action_dim,
        # in_ch = 14,
        base_ch = 24,
        max_tones = 128,
    ).to("cuda" if torch.cuda.is_available() else "cpu")

jve = JammerVecEnv(
        samples = train_loader,
        test_samples = test_loader,
        model = ac,
        jammer_sampling_freq = float(jammer_sampling_freq),
        num_envs = 1,
        reward_fn = None,
        user_peak_power_fraction= 1e6,
        max_steps = 1,
        device = device)

cfg = PPOConfig()

cfg.rollout_steps = jve._source_batches_per_epoch
test_no = 45

cfg.tensorboard_log_dir = f"runs/train_rl_loop_{test_no}"
cfg.checkpoint_dir = f"checkpoints_rl_{test_no}"
cfg.checkpoint_name = f"best_model_{test_no}.pt"

print(cfg.tensorboard_log_dir, cfg.checkpoint_dir, cfg.checkpoint_name)
cfg.value_coef = 0.5
cfg.epochs = 200

rsc = RewardScheduleConfig()

rsc.decode_every_n_steps = 1

p = train_rl_loop_batched_dsp(
    policy = jve.model,
    env = jve,
    cfg = cfg,
    reward_sched = rsc)


p
# Out:
# runs/train_rl_loop_45 checkpoints_rl_45 best_model_45.pt
# epoch=1/200 steps_per_epoch=1 train_loss=-9.2160 test_loss=-0.0000 train_decode_success_pct=80.00 test_decode_success_pct=100.00
# epoch=2/200 steps_per_epoch=1 train_loss=-190.0176 test_loss=-0.0000 train_decode_success_pct=60.00 test_decode_success_pct=100.00
# epoch=3/200 steps_per_epoch=1 train_loss=-118.4507 test_loss=-0.0000 train_decode_success_pct=78.00 test_decode_success_pct=100.00
# epoch=4/200 steps_per_epoch=1 train_loss=-183.5350 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=5/200 steps_per_epoch=1 train_loss=-173.1489 test_loss=-538.9196 train_decode_success_pct=68.00 test_decode_success_pct=0.00
# epoch=6/200 steps_per_epoch=1 train_loss=-147.7319 test_loss=-0.0000 train_decode_success_pct=72.00 test_decode_success_pct=100.00
# epoch=7/200 steps_per_epoch=1 train_loss=-204.7782 test_loss=-0.0000 train_decode_success_pct=62.00 test_decode_success_pct=100.00
# epoch=8/200 steps_per_epoch=1 train_loss=-291.2396 test_loss=-552.8499 train_decode_success_pct=46.00 test_decode_success_pct=0.00
# epoch=9/200 steps_per_epoch=1 train_loss=-195.8703 test_loss=-0.0000 train_decode_success_pct=64.00 test_decode_success_pct=100.00
# epoch=10/200 steps_per_epoch=1 train_loss=-160.9903 test_loss=-566.5537 train_decode_success_pct=70.00 test_decode_success_pct=0.00
# epoch=11/200 steps_per_epoch=1 train_loss=-137.4002 test_loss=-0.0000 train_decode_success_pct=74.00 test_decode_success_pct=100.00
# epoch=12/200 steps_per_epoch=1 train_loss=-203.5993 test_loss=-534.1613 train_decode_success_pct=62.00 test_decode_success_pct=0.00
# epoch=13/200 steps_per_epoch=1 train_loss=-161.9045 test_loss=-511.7206 train_decode_success_pct=70.00 test_decode_success_pct=0.00
# epoch=14/200 steps_per_epoch=1 train_loss=-193.1054 test_loss=-519.7737 train_decode_success_pct=64.00 test_decode_success_pct=0.00
# epoch=15/200 steps_per_epoch=1 train_loss=-182.3216 test_loss=-529.5681 train_decode_success_pct=66.00 test_decode_success_pct=0.00
# epoch=16/200 steps_per_epoch=1 train_loss=-194.4774 test_loss=-0.0000 train_decode_success_pct=64.00 test_decode_success_pct=100.00
# epoch=17/200 steps_per_epoch=1 train_loss=-246.7601 test_loss=-0.0000 train_decode_success_pct=54.00 test_decode_success_pct=100.00
# epoch=18/200 steps_per_epoch=1 train_loss=-291.9982 test_loss=-567.6628 train_decode_success_pct=46.00 test_decode_success_pct=0.00
# epoch=19/200 steps_per_epoch=1 train_loss=-181.9623 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=20/200 steps_per_epoch=1 train_loss=-139.4676 test_loss=-0.0000 train_decode_success_pct=74.00 test_decode_success_pct=100.00
# epoch=21/200 steps_per_epoch=1 train_loss=-140.4131 test_loss=-0.0000 train_decode_success_pct=74.00 test_decode_success_pct=100.00
# epoch=22/200 steps_per_epoch=1 train_loss=-183.7403 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=23/200 steps_per_epoch=1 train_loss=-152.6680 test_loss=-0.0000 train_decode_success_pct=72.00 test_decode_success_pct=100.00
# epoch=24/200 steps_per_epoch=1 train_loss=-172.8487 test_loss=-526.2928 train_decode_success_pct=68.00 test_decode_success_pct=0.00
# epoch=25/200 steps_per_epoch=1 train_loss=-162.3238 test_loss=-0.0000 train_decode_success_pct=70.00 test_decode_success_pct=100.00
# epoch=26/200 steps_per_epoch=1 train_loss=-195.3317 test_loss=-548.9873 train_decode_success_pct=64.00 test_decode_success_pct=0.00
# epoch=27/200 steps_per_epoch=1 train_loss=-194.0455 test_loss=-0.0000 train_decode_success_pct=64.00 test_decode_success_pct=100.00
# epoch=28/200 steps_per_epoch=1 train_loss=-258.6389 test_loss=-0.0000 train_decode_success_pct=52.00 test_decode_success_pct=100.00
# epoch=29/200 steps_per_epoch=1 train_loss=-179.6011 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=30/200 steps_per_epoch=1 train_loss=-107.0046 test_loss=-0.0000 train_decode_success_pct=80.00 test_decode_success_pct=100.00
# epoch=31/200 steps_per_epoch=1 train_loss=-182.3354 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=32/200 steps_per_epoch=1 train_loss=-139.4072 test_loss=-0.0000 train_decode_success_pct=74.00 test_decode_success_pct=100.00
# epoch=33/200 steps_per_epoch=1 train_loss=-118.5510 test_loss=-529.5428 train_decode_success_pct=78.00 test_decode_success_pct=0.00

# %%
max_tones = 128
max_pulses = 33
action_dim = 10 + 4*max_tones

action_dim = 11+4*max_tones+max_pulses

ac = ActorCritic(
        action_dim = action_dim,
        # in_ch = 14,
        base_ch = 24,
        max_tones = 128,
    ).to("cuda" if torch.cuda.is_available() else "cpu")

jve = JammerVecEnv(
        samples = train_loader,
        test_samples = test_loader,
        model = ac,
        jammer_sampling_freq = float(jammer_sampling_freq),
        num_envs = 1,
        reward_fn = None,
        user_peak_power_fraction= 1e6,
        max_steps = 1,
        device = device)

cfg = PPOConfig()

cfg.rollout_steps = jve._source_batches_per_epoch
test_no = 46

cfg.tensorboard_log_dir = f"runs/train_rl_loop_{test_no}"
cfg.checkpoint_dir = f"checkpoints_rl_{test_no}"
cfg.checkpoint_name = f"best_model_{test_no}.pt"

print(cfg.tensorboard_log_dir, cfg.checkpoint_dir, cfg.checkpoint_name)
cfg.value_coef = 0.5
cfg.epochs = 200

rsc = RewardScheduleConfig()

rsc.decode_every_n_steps = 1

p = train_rl_loop_batched_dsp(
    policy = jve.model,
    env = jve,
    cfg = cfg,
    reward_sched = rsc)


p
# Out:
# runs/train_rl_loop_46 checkpoints_rl_46 best_model_46.pt
# epoch=1/200 steps_per_epoch=1 train_loss=-32.6180 test_loss=-0.0000 train_decode_success_pct=70.00 test_decode_success_pct=100.00
# epoch=2/200 steps_per_epoch=1 train_loss=-177.5201 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=3/200 steps_per_epoch=1 train_loss=-171.5214 test_loss=-0.0000 train_decode_success_pct=68.00 test_decode_success_pct=100.00
# epoch=4/200 steps_per_epoch=1 train_loss=-128.5071 test_loss=-0.0000 train_decode_success_pct=76.00 test_decode_success_pct=100.00
# epoch=5/200 steps_per_epoch=1 train_loss=-171.4926 test_loss=-563.2148 train_decode_success_pct=68.00 test_decode_success_pct=0.00
# epoch=6/200 steps_per_epoch=1 train_loss=-171.8310 test_loss=-0.0000 train_decode_success_pct=68.00 test_decode_success_pct=100.00
# epoch=7/200 steps_per_epoch=1 train_loss=-183.9433 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=8/200 steps_per_epoch=1 train_loss=-162.0309 test_loss=-551.8567 train_decode_success_pct=70.00 test_decode_success_pct=0.00
# epoch=9/200 steps_per_epoch=1 train_loss=-226.0964 test_loss=-0.0000 train_decode_success_pct=58.00 test_decode_success_pct=100.00
# epoch=10/200 steps_per_epoch=1 train_loss=-203.4037 test_loss=-519.8645 train_decode_success_pct=62.00 test_decode_success_pct=0.00
# epoch=11/200 steps_per_epoch=1 train_loss=-205.2293 test_loss=-0.0000 train_decode_success_pct=62.00 test_decode_success_pct=100.00
# epoch=12/200 steps_per_epoch=1 train_loss=-182.9435 test_loss=-531.7090 train_decode_success_pct=66.00 test_decode_success_pct=0.00
# epoch=13/200 steps_per_epoch=1 train_loss=-172.0200 test_loss=-522.5552 train_decode_success_pct=68.00 test_decode_success_pct=0.00
# epoch=14/200 steps_per_epoch=1 train_loss=-160.9505 test_loss=-532.3989 train_decode_success_pct=70.00 test_decode_success_pct=0.00
# epoch=15/200 steps_per_epoch=1 train_loss=-162.5456 test_loss=-545.5161 train_decode_success_pct=70.00 test_decode_success_pct=0.00
# epoch=16/200 steps_per_epoch=1 train_loss=-215.2584 test_loss=-0.0000 train_decode_success_pct=60.00 test_decode_success_pct=100.00
# epoch=17/200 steps_per_epoch=1 train_loss=-204.9197 test_loss=-0.0000 train_decode_success_pct=62.00 test_decode_success_pct=100.00
# epoch=18/200 steps_per_epoch=1 train_loss=-171.6744 test_loss=-538.3685 train_decode_success_pct=68.00 test_decode_success_pct=0.00
# epoch=19/200 steps_per_epoch=1 train_loss=-160.9095 test_loss=-0.0000 train_decode_success_pct=70.00 test_decode_success_pct=100.00
# epoch=20/200 steps_per_epoch=1 train_loss=-185.3594 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=21/200 steps_per_epoch=1 train_loss=-202.0056 test_loss=-0.0000 train_decode_success_pct=62.00 test_decode_success_pct=100.00
# epoch=22/200 steps_per_epoch=1 train_loss=-172.1391 test_loss=-0.0000 train_decode_success_pct=68.00 test_decode_success_pct=100.00
# epoch=23/200 steps_per_epoch=1 train_loss=-65.0573 test_loss=-0.0000 train_decode_success_pct=88.00 test_decode_success_pct=100.00
# epoch=24/200 steps_per_epoch=1 train_loss=-173.4484 test_loss=-0.0000 train_decode_success_pct=68.00 test_decode_success_pct=100.00
# epoch=25/200 steps_per_epoch=1 train_loss=-151.8375 test_loss=-0.0000 train_decode_success_pct=72.00 test_decode_success_pct=100.00
# epoch=26/200 steps_per_epoch=1 train_loss=-180.5866 test_loss=-539.1270 train_decode_success_pct=66.00 test_decode_success_pct=0.00
# epoch=27/200 steps_per_epoch=1 train_loss=-183.6771 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=28/200 steps_per_epoch=1 train_loss=-225.0202 test_loss=-0.0000 train_decode_success_pct=58.00 test_decode_success_pct=100.00
# epoch=29/200 steps_per_epoch=1 train_loss=-170.8602 test_loss=-0.0000 train_decode_success_pct=68.00 test_decode_success_pct=100.00
# epoch=30/200 steps_per_epoch=1 train_loss=-192.6202 test_loss=-0.0000 train_decode_success_pct=64.00 test_decode_success_pct=100.00
# epoch=31/200 steps_per_epoch=1 train_loss=-224.5351 test_loss=-0.0000 train_decode_success_pct=58.00 test_decode_success_pct=100.00
# epoch=32/200 steps_per_epoch=1 train_loss=-214.1329 test_loss=-0.0000 train_decode_success_pct=60.00 test_decode_success_pct=100.00
# epoch=33/200 steps_per_epoch=1 train_loss=-128.7659 test_loss=-0.0000 train_decode_success_pct=76.00 test_decode_success_pct=100.00
# epoch=34/200 steps_per_epoch=1 train_loss=-162.5976 test_loss=-0.0000 train_decode_success_pct=70.00 test_decode_success_pct=100.00
# epoch=35/200 steps_per_epoch=1 train_loss=-162.4871 test_loss=-0.0000 train_decode_success_pct=70.00 test_decode_success_pct=100.00
# epoch=36/200 steps_per_epoch=1 train_loss=-182.7383 test_loss=-542.5972 train_decode_success_pct=66.00 test_decode_success_pct=0.00
# epoch=37/200 steps_per_epoch=1 train_loss=-172.3002 test_loss=-0.0000 train_decode_success_pct=68.00 test_decode_success_pct=100.00
# epoch=38/200 steps_per_epoch=1 train_loss=-203.9375 test_loss=-0.0000 train_decode_success_pct=62.00 test_decode_success_pct=100.00
# epoch=39/200 steps_per_epoch=1 train_loss=-172.2873 test_loss=-529.6976 train_decode_success_pct=68.00 test_decode_success_pct=0.00
# epoch=40/200 steps_per_epoch=1 train_loss=-205.4451 test_loss=-0.0000 train_decode_success_pct=62.00 test_decode_success_pct=100.00
# epoch=41/200 steps_per_epoch=1 train_loss=-160.6034 test_loss=-0.0000 train_decode_success_pct=70.00 test_decode_success_pct=100.00
# epoch=42/200 steps_per_epoch=1 train_loss=-194.0454 test_loss=-548.2982 train_decode_success_pct=64.00 test_decode_success_pct=0.00
# epoch=43/200 steps_per_epoch=1 train_loss=-118.2016 test_loss=-542.2959 train_decode_success_pct=78.00 test_decode_success_pct=0.00
# epoch=44/200 steps_per_epoch=1 train_loss=-181.1547 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=45/200 steps_per_epoch=1 train_loss=-161.1212 test_loss=-0.0000 train_decode_success_pct=70.00 test_decode_success_pct=100.00
# epoch=46/200 steps_per_epoch=1 train_loss=-181.6582 test_loss=-0.0000 train_decode_success_pct=66.00 test_decode_success_pct=100.00
# epoch=47/200 steps_per_epoch=1 train_loss=-206.3639 test_loss=-0.0000 train_decode_success_pct=62.00 test_decode_success_pct=100.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 42
#      38 rsc = RewardScheduleConfig()
#      40 rsc.decode_every_n_steps = 1
# ---> 42 p = train_rl_loop_batched_dsp(
#      43     policy = jve.model,
#      44     env = jve,
#      45     cfg = cfg,
#      46     reward_sched = rsc)
#      49 p
#
# Cell In[5], line 188, in train_rl_loop_batched_dsp(policy, env, cfg, reward_sched)
#     177 active_samples = list(env._active)
#     179 jam_batch = jammer_controller_batch(
#     180     model=env.model,
#     181     samples=active_samples,
#    (...)    185     device=env.device,
#     186 )
# --> 188 rewards_t, success, total = compute_rewards_scheduled_batched(
#     189     jam_batch=jam_batch,
#     190     samples=active_samples,
#     191     jammer_sampling_freq=float(env.jammer_sampling_freq),
#     192     device=device,
#     193     step_idx=global_step,
#     194     sched=reward_sched,
#     195 )
#     196 epoch_success += int(success)
#     197 epoch_total += int(total)
#
# Cell In[4], line 61, in compute_rewards_scheduled_batched(jam_batch, samples, jammer_sampling_freq, device, step_idx, sched)
#      58 jammed_pad = [torch.nn.functional.pad(x, (0, max_len - int(x.numel()))) for x in jammed_rows]
#      59 jammed_batch = torch.stack(jammed_pad, dim=0).to(device=dev, dtype=torch.complex64)
# ---> 61 results = _batched_decode(jammed_batch, metas)
#      63 scores: List[torch.Tensor] = []
#      64 success = 0
#
# Cell In[4], line 9, in _batched_decode(iq_batch, meta_list)
#       7 def _batched_decode(iq_batch: torch.Tensor, meta_list: Sequence[Dict[str, Any]]) -> List[Dict[str, Any]]:
#       8     if hasattr(link7, "rx_command_iq_broadcast"):
# ----> 9         return link7.rx_command_iq_broadcast(iq_batch, list(meta_list))
#      10     return [link7.rx_command_iq(iq_batch[i], meta_list[i]) for i in range(iq_batch.shape[0])]
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1937, in rx_command_iq_broadcast(iq_batch, meta_list)
#    1934     continue
#    1936 try:
# -> 1937     results.append(rx_command_iq(iq_i, meta_i))
#    1938 except Exception as exc:
#    1939     results.append({
#    1940         "payload_bytes": None,
#    1941         "payload_len": 0,
#    (...)   1947         "error": str(exc),
#    1948     })
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1822, in rx_command_iq(iq, meta)
#    1812 access_ref_waveform = get_cached_access_ref(sps=sps, beta=beta, span=span, device=iq.device)
#    1814 # loop_coarse_start, loop_coarse_cfo_hz, loop_coarse_metric = loop_coarse_frequency_acquire(
#    1815 #     iq=iq,
#    1816 #     ref_waveform=access_ref_waveform,
#    (...)   1819 #     n_bins=coarse_freq_bins,
#    1820 # )
# -> 1822 coarse_start, coarse_cfo_hz, coarse_metric, metric_div = coarse_frequency_acquire(
#    1823     iq=iq,
#    1824     ref_waveform=access_ref_waveform,
#    1825     sample_rate_hz=dsp_sample_rate_hz,
#    1826     search_hz=coarse_freq_search_hz,
#    1827     n_bins=coarse_freq_bins,
#    1828 )
#    1830 # print(f'coarse_start: {coarse_start}, coarse_cfo_hz : {coarse_cfo_hz}, coarse_metric : {coarse_metric}')
#    1832 iq = apply_carrier_frequency(iq, carrier_hz=-coarse_cfo_hz, sample_rate_hz=dsp_sample_rate_hz)
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1326, in coarse_frequency_acquire(iq, ref_waveform, sample_rate_hz, search_hz, n_bins, coarse_bins, chunk_bins)
#    1324 coarse_bins = max(5, min(int(coarse_bins), int(n_bins)))
#    1325 coarse_grid = torch.linspace(-search_hz, search_hz, coarse_bins, dtype=torch.float64, device=x.device)
# -> 1326 _, coarse_cfo, _, coarse_scores = _scan_bins(coarse_grid)
#    1328 refine_step_hz = (2.0 * search_hz) / max(1, coarse_bins - 1)
#    1329 fine_half_span = max(refine_step_hz, search_hz / max(1.0, coarse_bins / 2.0))
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1314, in coarse_frequency_acquire.<locals>._scan_bins(bins)
#    1312 metrics, idxs = torch.max(mag, dim=1)
#    1313 per_bin_scores.append(metrics)
# -> 1314 local_best = int(torch.argmax(metrics).item())
#    1315 local_metric = float(metrics[local_best].item())
#    1316 if local_metric > best_metric_local:
#
# KeyboardInterrupt:

# %%
max_tones = 128
max_pulses = 33
action_dim = 10 + 4*max_tones

action_dim = 11+4*max_tones+max_pulses

ac = ActorCritic(
        action_dim = action_dim,
        # in_ch = 14,
        base_ch = 24,
        max_tones = 128,
    ).to("cuda" if torch.cuda.is_available() else "cpu")

jve = JammerVecEnv(
        samples = train_loader,
        test_samples = test_loader,
        model = ac,
        jammer_sampling_freq = float(jammer_sampling_freq),
        num_envs = 1,
        reward_fn = None,
        user_peak_power_fraction= float(1e-23),
        max_steps = 1,
        device = device)

cfg = PPOConfig()

cfg.rollout_steps = jve._source_batches_per_epoch
test_no = 47

cfg.tensorboard_log_dir = f"runs/train_rl_loop_{test_no}"
cfg.checkpoint_dir = f"checkpoints_rl_{test_no}"
cfg.checkpoint_name = f"best_model_{test_no}.pt"

print(cfg.tensorboard_log_dir, cfg.checkpoint_dir, cfg.checkpoint_name)
cfg.value_coef = 0.5
cfg.epochs = 200

rsc = RewardScheduleConfig()

rsc.decode_every_n_steps = 1

p = train_rl_loop_batched_dsp(
    policy = jve.model,
    env = jve,
    cfg = cfg,
    reward_sched = rsc)


p
# Out:
# runs/train_rl_loop_47 checkpoints_rl_47 best_model_47.pt
# epoch=1/200 steps_per_epoch=1 train_loss=-228.7047 test_loss=-517.4390 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=2/200 steps_per_epoch=1 train_loss=-532.7892 test_loss=-561.3646 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=3/200 steps_per_epoch=1 train_loss=-533.5532 test_loss=-544.0496 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=4/200 steps_per_epoch=1 train_loss=-539.6024 test_loss=-546.6572 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=5/200 steps_per_epoch=1 train_loss=-534.0053 test_loss=-533.0710 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=6/200 steps_per_epoch=1 train_loss=-537.7073 test_loss=-544.1500 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=7/200 steps_per_epoch=1 train_loss=-538.0186 test_loss=-528.1768 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=8/200 steps_per_epoch=1 train_loss=-538.2564 test_loss=-539.0078 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=9/200 steps_per_epoch=1 train_loss=-538.0183 test_loss=-541.6080 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=10/200 steps_per_epoch=1 train_loss=-539.4425 test_loss=-548.3258 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=11/200 steps_per_epoch=1 train_loss=-537.7613 test_loss=-545.4377 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=12/200 steps_per_epoch=1 train_loss=-539.6386 test_loss=-514.9044 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=13/200 steps_per_epoch=1 train_loss=-541.3864 test_loss=-547.0000 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=14/200 steps_per_epoch=1 train_loss=-538.5417 test_loss=-534.4059 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=15/200 steps_per_epoch=1 train_loss=-538.1650 test_loss=-529.5754 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=16/200 steps_per_epoch=1 train_loss=-536.5481 test_loss=-544.8911 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=17/200 steps_per_epoch=1 train_loss=-535.6590 test_loss=-519.9681 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=18/200 steps_per_epoch=1 train_loss=-534.5425 test_loss=-528.3573 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=19/200 steps_per_epoch=1 train_loss=-540.3380 test_loss=-547.7183 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=20/200 steps_per_epoch=1 train_loss=-536.9207 test_loss=-543.4553 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=21/200 steps_per_epoch=1 train_loss=-540.3922 test_loss=-529.3987 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=22/200 steps_per_epoch=1 train_loss=-539.6316 test_loss=-515.1800 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=23/200 steps_per_epoch=1 train_loss=-539.1970 test_loss=-526.3030 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=24/200 steps_per_epoch=1 train_loss=-538.1695 test_loss=-519.5734 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=25/200 steps_per_epoch=1 train_loss=-539.0135 test_loss=-512.1156 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# epoch=26/200 steps_per_epoch=1 train_loss=-540.7778 test_loss=-535.8748 train_decode_success_pct=0.00 test_decode_success_pct=0.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 42
#      38 rsc = RewardScheduleConfig()
#      40 rsc.decode_every_n_steps = 1
# ---> 42 p = train_rl_loop_batched_dsp(
#      43     policy = jve.model,
#      44     env = jve,
#      45     cfg = cfg,
#      46     reward_sched = rsc)
#      49 p
#
# Cell In[5], line 188, in train_rl_loop_batched_dsp(policy, env, cfg, reward_sched)
#     177 active_samples = list(env._active)
#     179 jam_batch = jammer_controller_batch(
#     180     model=env.model,
#     181     samples=active_samples,
#    (...)    185     device=env.device,
#     186 )
# --> 188 rewards_t, success, total = compute_rewards_scheduled_batched(
#     189     jam_batch=jam_batch,
#     190     samples=active_samples,
#     191     jammer_sampling_freq=float(env.jammer_sampling_freq),
#     192     device=device,
#     193     step_idx=global_step,
#     194     sched=reward_sched,
#     195 )
#     196 epoch_success += int(success)
#     197 epoch_total += int(total)
#
# Cell In[4], line 61, in compute_rewards_scheduled_batched(jam_batch, samples, jammer_sampling_freq, device, step_idx, sched)
#      58 jammed_pad = [torch.nn.functional.pad(x, (0, max_len - int(x.numel()))) for x in jammed_rows]
#      59 jammed_batch = torch.stack(jammed_pad, dim=0).to(device=dev, dtype=torch.complex64)
# ---> 61 results = _batched_decode(jammed_batch, metas)
#      63 scores: List[torch.Tensor] = []
#      64 success = 0
#
# Cell In[4], line 9, in _batched_decode(iq_batch, meta_list)
#       7 def _batched_decode(iq_batch: torch.Tensor, meta_list: Sequence[Dict[str, Any]]) -> List[Dict[str, Any]]:
#       8     if hasattr(link7, "rx_command_iq_broadcast"):
# ----> 9         return link7.rx_command_iq_broadcast(iq_batch, list(meta_list))
#      10     return [link7.rx_command_iq(iq_batch[i], meta_list[i]) for i in range(iq_batch.shape[0])]
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1937, in rx_command_iq_broadcast(iq_batch, meta_list)
#    1934     continue
#    1936 try:
# -> 1937     results.append(rx_command_iq(iq_i, meta_i))
#    1938 except Exception as exc:
#    1939     results.append({
#    1940         "payload_bytes": None,
#    1941         "payload_len": 0,
#    (...)   1947         "error": str(exc),
#    1948     })
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1822, in rx_command_iq(iq, meta)
#    1812 access_ref_waveform = get_cached_access_ref(sps=sps, beta=beta, span=span, device=iq.device)
#    1814 # loop_coarse_start, loop_coarse_cfo_hz, loop_coarse_metric = loop_coarse_frequency_acquire(
#    1815 #     iq=iq,
#    1816 #     ref_waveform=access_ref_waveform,
#    (...)   1819 #     n_bins=coarse_freq_bins,
#    1820 # )
# -> 1822 coarse_start, coarse_cfo_hz, coarse_metric, metric_div = coarse_frequency_acquire(
#    1823     iq=iq,
#    1824     ref_waveform=access_ref_waveform,
#    1825     sample_rate_hz=dsp_sample_rate_hz,
#    1826     search_hz=coarse_freq_search_hz,
#    1827     n_bins=coarse_freq_bins,
#    1828 )
#    1830 # print(f'coarse_start: {coarse_start}, coarse_cfo_hz : {coarse_cfo_hz}, coarse_metric : {coarse_metric}')
#    1832 iq = apply_carrier_frequency(iq, carrier_hz=-coarse_cfo_hz, sample_rate_hz=dsp_sample_rate_hz)
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1334, in coarse_frequency_acquire(iq, ref_waveform, sample_rate_hz, search_hz, n_bins, coarse_bins, chunk_bins)
#    1331 fine_high = min(search_hz, coarse_cfo + fine_half_span)
#    1332 fine_grid = torch.linspace(fine_low, fine_high, int(n_bins), dtype=torch.float64, device=x.device)
# -> 1334 best_start, best_cfo, best_metric, fine_scores = _scan_bins(fine_grid)
#    1336 scores = torch.cat([coarse_scores.to(torch.float32), fine_scores.to(torch.float32)])
#    1337 std = torch.std(scores).clamp_min(1e-6)
#
# File ~\Jamming\Conserve\advanced_link_skdsp_v7_robust.py:1314, in coarse_frequency_acquire.<locals>._scan_bins(bins)
#    1312 metrics, idxs = torch.max(mag, dim=1)
#    1313 per_bin_scores.append(metrics)
# -> 1314 local_best = int(torch.argmax(metrics).item())
#    1315 local_metric = float(metrics[local_best].item())
#    1316 if local_metric > best_metric_local:
#
# KeyboardInterrupt:
